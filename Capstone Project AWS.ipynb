# %% [markdown]
# # US Immigration And Its Contributing Factors
# ### Data Engineering Capstone Project
#
# #### Project Summary
# This project studies the relationship between the immigrants to US states and the population demographics, the temperature, and the airports.
# It uses STAR schema to create different dimension and fact tables based on the data sourced publicily.
# The processes developed in this Jupyter Notebook is based on premise tools.
# It uses sqlite to build a data warehouse and develops ETL scripts with Python and SQL.
#
# The project follows the following steps:
# * [Step 1: Scope the Project and Gather Data](#step1)
# * [Step 2: Explore and Assess the Data](#step2)
# * [Step 3: Define the Data Model](#model)
# * [Step 4: Run ETL to Model the Data](#check)
# * [Step 5: Complete Project Write Up](#complete)

# %%
# !pip install --upgrade pandas

# %%
# !pip install --upgrade numpy

# %%
# !pip install --upgrade numexpr

# %%
# !pip install ipython-sql

# %%
#!pip install pyspark-pandas

# %%
# !pyspark --version

# %%
# Do all imports and installs here
import pandas as pd
import numpy as np
from io import StringIO
import configparser
from sqlalchemy import create_engine
import os
import boto3 # aws Python API
from pyspark.sql import SparkSession
from pyspark.sql.functions import to_date, col, date_add, expr, regexp_replace
import psycopg2

# %%
# engine = sqlalchemy.create_engine('postgres://username:password@url:5439/db_name')

# %%
# show all the columns
pd.set_option('display.max_columns', None)

# %%
# Run sql query
# %load_ext sql

# %%
# get the parameter from aws configure file
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY =config.get('AWS', 'KEY')
SECRET =config.get('AWS', 'SECRET')

ARN = config.get('IAM_ROLE', 'ARN')

DWH_ENDPOINT = config.get("CLUSTER", "HOST")
DWH_DB = config.get("CLUSTER", "DB_NAME") 
DWH_DB_USER = config.get("CLUSTER", "DB_USER") 
DWH_DB_PASSWORD = config.get("CLUSTER", "DB_PASSWORD")
DWH_PORT = config.get("CLUSTER", "DB_PORT")

# %%
# confire AWS credentials
os.environ['AWS_ACCESS_KEY_ID']=config.get('AWS', 'KEY')
os.environ['AWS_SECRET_ACCESS_KEY']=config.get('AWS', 'SECRET')

# %%
# print(config.get('AWS', 'KEY'), config.get('AWS', 'SECRET'))

# %% [markdown]
# <a id='step1'></a>

# %% [markdown]
# ### Step 1: Scope the Project and Gather Data
#
# #### Scope
# 1. **Purpose**: The relationship among immigrants, temperature, population, and airports.
# 2. **Data**: immigrants, temperature, population, and airports data.
# 3. **Solution**: dimension tables for temperature, population, airports and fact tables for tourists.
# 4. **Tools**: sqlite, Python, SQL
# #### Describe and Gather Data
# - **Immigrants**: immigrants and their demographics; [Source](https://www.trade.gov/national-travel-and-tourism-office)
# - **Temperature**: average temperature; [Source](https://www.kaggle.com/datasets/berkeleyearth/climate-change-earth-surface-temperature-data?resource=download)
# - **Population**: population and its demographics; [Source](https://public.opendatasoft.com/explore/dataset/us-cities-demographics/export/)
# - **Airports**: airport type and features; [Source](https://datahub.io/core/airport-codes#pandas)

# %% [markdown]
# <a id="step2"></a>

# %% [markdown]
# ### Step 2: Explore and Assess the Data
# #### Explore the Data
# [Identify data quality issues, like missing values, duplicate data, etc.](#identify)
# - [airport](#airport)
# - [immigration](#immigration)
# - [cities](#city)
# - [temperature](#temperature)
# #### Cleaning Steps
# [Document steps necessary to clean the data](#clean)

# %% [markdown]
# <a id="identify"></a>

# %% [markdown]
# #### 2.1 Explore the data ####

# %% [markdown]
# <a id="airport"></a>

# %% [markdown]
# [airport](https://datahub.io/core/airport-codes#pandas)

# %%
# Read data
# read data as "string" format to ensure all the information is correct
airport = pd.read_csv("../airport-codes_csv.csv", dtype="str")

# %%
# airport summary
airport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55075 entries, 0 to 55074
# Data columns (total 12 columns):
# ident           55075 non-null object
# type            55075 non-null object
# name            55075 non-null object
# elevation_ft    48069 non-null object
# continent       27356 non-null object
# iso_country     54828 non-null object
# iso_region      55075 non-null object
# municipality    49399 non-null object
# gps_code        41030 non-null object
# iata_code       9189 non-null object
# local_code      28686 non-null object
# coordinates     55075 non-null object
# dtypes: object(12)
# memory usage: 5.0+ MB

# %% [markdown]
# **Notes**:
# 1. All types are "object". Need to be changed to the right formats.

# %%
# top 5
airport.head()
# Out:
#   ident           type                                name elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport           11
# 1  00AA  small_airport                Aero B Ranch Airport         3435
# 2  00AK  small_airport                        Lowell Field          450
# 3  00AL  small_airport                        Epps Airpark          820
# 4  00AR         closed  Newport Hospital & Clinic Heliport          237
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4        NaN                    -91.254898, 35.6087

# %% [markdown]
# **Notes**:
# 1. "iso_country" contains country and "iso_region" is combined by country and state.
# 2. "coordinates" needs to be separated by two columns "longitude" and "latitude".

# %%
# airport unique values 
airport.nunique()
# Out:
# ident           55075
# type                7
# name            52144
# elevation_ft     5449
# continent           6
# iso_country       243
# iso_region       2810
# municipality    27133
# gps_code        40850
# iata_code        9042
# local_code      27436
# coordinates     54874
# dtype: int64

# %%
# NaN rows
airport[airport.isnull().any(axis=1)]
# Out:
#          ident            type                                      name  \
# 0          00A        heliport                         Total Rf Heliport
# 1         00AA   small_airport                      Aero B Ranch Airport
# 2         00AK   small_airport                              Lowell Field
# 3         00AL   small_airport                              Epps Airpark
# 4         00AR          closed        Newport Hospital & Clinic Heliport
# 5         00AS   small_airport                            Fulton Airport
# 6         00AZ   small_airport                            Cordes Airport
# 7         00CA   small_airport                   Goldstone /Gts/ Airport
# 8         00CL   small_airport                       Williams Ag Airport
# 9         00CN        heliport           Kitchen Creek Helibase Heliport
# 10        00CO          closed                                Cass Field
# 11        00FA   small_airport                       Grass Patch Airport
# 12        00FD        heliport                        Ringhaver Heliport
# 13        00FL   small_airport                         River Oak Airport
# 14        00GA   small_airport                          Lt World Airport
# 15        00GE        heliport                          Caffrey Heliport
# 16        00HI        heliport                        Kaupulehu Heliport
# 17        00ID   small_airport                      Delta Shores Airport
# 18        00IG   small_airport                             Goltl Airport
# 19        00II        heliport        Bailey Generation Station Heliport
# 20        00IL   small_airport                            Hammer Airport
# 21        00IN        heliport           St Mary Medical Center Heliport
# 22        00IS   small_airport         Hayenga's Cant Find Farms Airport
# 23        00KS   small_airport                       Hayden Farm Airport
# 24        00KY   small_airport                     Robbins Roost Airport
# 25        00LA        heliport         Shell Chemical East Site Heliport
# 26        00LL        heliport                Ac & R Components Heliport
# 27        00LS   small_airport                           Lejeune Airport
# 28        00MD   small_airport                              Slater Field
# 29        00MI        heliport                     Dow Chemical Heliport
# ...        ...             ...                                       ...
# 55045     ZYAS  medium_airport                           Anshan Air Base
# 55046     ZYCC  medium_airport                           Longjia Airport
# 55047     ZYCH  medium_airport                          Changhai Airport
# 55048     ZYCY  medium_airport                          Chaoyang Airport
# 55049     ZYDU  medium_airport                  Wudalianchi Dedu Airport
# 55050     ZYFX   small_airport                             Fuxin Airport
# 55051     ZYFY  medium_airport                             Dongji Aiport
# 55052     ZYHB   large_airport                           Taiping Airport
# 55053     ZYHE  medium_airport                             Heihe Airport
# 55054     ZYJL   small_airport                             Jilin Airport
# 55055     ZYJM  medium_airport                           Jiamusi Airport
# 55056     ZYJS  medium_airport                      Jiansanjiang Airport
# 55057     ZYJX  medium_airport                    Jixi Xingkaihu Airport
# 55058     ZYJZ  medium_airport                           Jinzhou Airport
# 55059     ZYLD  medium_airport                             Lindu Airport
# 55060     ZYLS  medium_airport                      Yushu Batang Airport
# 55061     ZYMD  medium_airport  Mudanjiang Hailang International Airport
# 55062     ZYMH  medium_airport                           Gu-Lian Airport
# 55063     ZYQQ  medium_airport                  Qiqihar Sanjiazi Airport
# 55064     ZYSQ  medium_airport                 Songyuan Chaganhu Airport
# 55065     ZYTH   small_airport                              Tahe Airport
# 55066     ZYTL   large_airport                        Zhoushuizi Airport
# 55067     ZYTN  medium_airport                 Tonghua Sanyuanpu Airport
# 55068     ZYTX   large_airport                           Taoxian Airport
# 55069     ZYYJ  medium_airport               Yanji Chaoyangchuan Airport
# 55070     ZYYK  medium_airport                     Yingkou Lanqi Airport
# 55071     ZYYY  medium_airport                   Shenyang Dongta Airport
# 55072  ZZ-0001        heliport                           Sealand Helipad
# 55073  ZZ-0002   small_airport                 Glorioso Islands Airstrip
# 55074     ZZZZ   small_airport                   Satsuma IÅjima Airport
#
#       elevation_ft continent iso_country iso_region  \
# 0               11       NaN          US      US-PA
# 1             3435       NaN          US      US-KS
# 2              450       NaN          US      US-AK
# 3              820       NaN          US      US-AL
# 4              237       NaN          US      US-AR
# 5             1100       NaN          US      US-OK
# 6             3810       NaN          US      US-AZ
# 7             3038       NaN          US      US-CA
# 8               87       NaN          US      US-CA
# 9             3350       NaN          US      US-CA
# 10            4830       NaN          US      US-CO
# 11              53       NaN          US      US-FL
# 12              25       NaN          US      US-FL
# 13              35       NaN          US      US-FL
# 14             700       NaN          US      US-GA
# 15             957       NaN          US      US-GA
# 16              43       NaN          US      US-HI
# 17            2064       NaN          US      US-ID
# 18            3359       NaN          US      US-KS
# 19             600       NaN          US      US-IN
# 20             840       NaN          US      US-IL
# 21             634       NaN          US      US-IN
# 22             820       NaN          US      US-IL
# 23            1100       NaN          US      US-KS
# 24            1265       NaN          US      US-KY
# 25              15       NaN          US      US-LA
# 26             600       NaN          US      US-IL
# 27              12       NaN          US      US-LA
# 28              45       NaN          US      US-MD
# 29             588       NaN          US      US-MI
# ...            ...       ...         ...        ...
# 55045          NaN        AS          CN      CN-21
# 55046          706        AS          CN      CN-22
# 55047           80        AS          CN      CN-21
# 55048          568        AS          CN      CN-21
# 55049          984        AS          CN      CN-23
# 55050          548        AS          CN      CN-21
# 55051          NaN        AS          CN      CN-23
# 55052          457        AS          CN      CN-23
# 55053         8530        AS          CN      CN-23
# 55054          NaN        AS          CN      CN-22
# 55055          262        AS          CN      CN-23
# 55056          NaN        AS          CN      CN-23
# 55057          760        AS          CN      CN-23
# 55058          NaN        AS          CN      CN-21
# 55059          791        AS          CN      CN-23
# 55060        12816        AS          CN      CN-63
# 55061          883        AS          CN      CN-23
# 55062         1836        AS          CN      CN-23
# 55063          477        AS          CN      CN-23
# 55064          459        AS          CN      CN-22
# 55065         1240        AS          CN      CN-23
# 55066          107        AS          CN      CN-21
# 55067         1200        AS          CN      CN-22
# 55068          198        AS          CN      CN-21
# 55069          624        AS          CN      CN-22
# 55070            0        AS          CN      CN-21
# 55071          NaN        AS          CN      CN-21
# 55072           40        EU          GB     GB-ENG
# 55073           11        AF          TF     TF-U-A
# 55074          338        AS          JP      JP-46
#
#                                municipality gps_code iata_code local_code  \
# 0                                  Bensalem      00A       NaN        00A
# 1                                     Leoti     00AA       NaN       00AA
# 2                              Anchor Point     00AK       NaN       00AK
# 3                                   Harvest     00AL       NaN       00AL
# 4                                   Newport      NaN       NaN        NaN
# 5                                      Alex     00AS       NaN       00AS
# 6                                    Cordes     00AZ       NaN       00AZ
# 7                                   Barstow     00CA       NaN       00CA
# 8                                     Biggs     00CL       NaN       00CL
# 9                               Pine Valley     00CN       NaN       00CN
# 10                               Briggsdale      NaN       NaN        NaN
# 11                                 Bushnell     00FA       NaN       00FA
# 12                                Riverview     00FD       NaN       00FD
# 13                               Okeechobee     00FL       NaN       00FL
# 14                                 Lithonia     00GA       NaN       00GA
# 15                                    Hiram     00GE       NaN       00GE
# 16                              Kailua/Kona     00HI       NaN       00HI
# 17                               Clark Fork     00ID       NaN       00ID
# 18                                 McDonald     00IG       NaN       00IG
# 19                               Chesterton     00II       NaN       00II
# 20                                     Polo     00IL       NaN       00IL
# 21                                   Hobart     00IN       NaN       00IN
# 22                                    Kings     00IS       NaN       00IS
# 23                                  Gardner     00KS       NaN       00KS
# 24                                 Stanford     00KY       NaN       00KY
# 25                                 Gonzales     00LA       NaN       00LA
# 26                                  Chatham     00LL       NaN       00LL
# 27                                Esterwood     00LS       NaN       00LS
# 28                             Federalsburg     00MD       NaN       00MD
# 29                                Ludington     00MI       NaN       00MI
# ...                                     ...      ...       ...        ...
# 55045                                Anshan     ZYAS       AOG        NaN
# 55046                             Changchun     ZYCC       CGQ        NaN
# 55047                              Changhai     ZYCH       CNI        NaN
# 55048                              Chaoyang     ZYCY       CHG        NaN
# 55049                           Wudalianchi     ZYDU       DTU        NaN
# 55050                                 Fuxin     ZYFX       NaN        NaN
# 55051                                Fuyuan     ZYFY       FYJ        NaN
# 55052                                Harbin     ZYHB       HRB        NaN
# 55053                                 Heihe     ZYHE       HEK        NaN
# 55054                                 Jilin     ZYJL       JIL        NaN
# 55055                               Jiamusi     ZYJM       JMU        NaN
# 55056                          Jiansanjiang     ZYJS       JSJ        NaN
# 55057                                  Jixi     ZYJX       JXA        NaN
# 55058                               Jinzhou     ZYJZ       JNZ        NaN
# 55059                                Yichun     ZYLD       LDS        NaN
# 55060                                 Yushu     ZYLS       YUS        NaN
# 55061                            Mudanjiang     ZYMD       MDG        NaN
# 55062                                  Mohe     ZYMH       OHE        NaN
# 55063                               Qiqihar     ZYQQ       NDG        NaN
# 55064  Qian Gorlos Mongol Autonomous County     ZYSQ       YSQ        NaN
# 55065                                  Tahe     ZYTH       NaN        NaN
# 55066                                Dalian     ZYTL       DLC        NaN
# 55067                               Tonghua     ZYTN       TNH        NaN
# 55068                              Shenyang     ZYTX       SHE        NaN
# 55069                                 Yanji     ZYYJ       YNJ        NaN
# 55070                               Yingkou     ZYYK       YKH        NaN
# 55071                              Shenyang     ZYYY       NaN        NaN
# 55072                               Sealand      NaN       NaN        NaN
# 55073                      Grande Glorieuse      NaN       NaN        NaN
# 55074                          Mishima-Mura     RJX7       NaN        NaN
#
#                                    coordinates
# 0           -74.93360137939453, 40.07080078125
# 1                       -101.473911, 38.704022
# 2                  -151.695999146, 59.94919968
# 3        -86.77030181884766, 34.86479949951172
# 4                          -91.254898, 35.6087
# 5                      -97.8180194, 34.9428028
# 6      -112.16500091552734, 34.305599212646484
# 7           -116.888000488, 35.350498199499995
# 8                       -121.763427, 39.427188
# 9                     -116.4597417, 32.7273736
# 10                      -104.344002, 40.622202
# 11       -82.21900177001953, 28.64550018310547
# 12      -82.34539794921875, 28.846599578857422
# 13      -80.96920013427734, 27.230899810791016
# 14       -84.06829833984375, 33.76750183105469
# 15       -84.73390197753906, 33.88420104980469
# 16                      -155.980233, 19.832715
# 17     -116.21399688720703, 48.145301818847656
# 18                      -101.395994, 39.724028
# 19        -87.122802734375, 41.644500732421875
# 20        -89.5604019165039, 41.97840118408203
# 21        -87.2605972290039, 41.51139831542969
# 22        -89.1229019165039, 40.02560043334961
# 23       -94.93049621582031, 38.72779846191406
# 24      -84.61969757080078, 37.409400939941406
# 25                       -90.980833, 30.191944
# 26       -89.70559692382812, 39.66529846191406
# 27       -92.42939758300781, 30.13629913330078
# 28       -75.75379943847656, 38.75709915161133
# 29       -86.41670227050781, 43.94940185546875
# ...                                        ...
# 55045                    122.853996, 41.105301
# 55046             125.684997559, 43.9962005615
# 55047             122.666944444, 39.2666666667
# 55048                    120.434998, 41.538101
# 55049                          126.133, 48.445
# 55050                    121.718122, 42.069014
# 55051                    134.366447, 48.199494
# 55052                 126.25, 45.6234016418457
# 55053             127.308883667, 50.1716209371
# 55054                    126.396004, 44.002201
# 55055         130.464996338, 46.84339904789999
# 55056                        132.660278, 47.11
# 55057                          131.193, 45.293
# 55058    121.06199645996094, 41.10139846801758
# 55059                129.019125, 47.7520555556
# 55060        97.0363888889, 32.836388888900004
# 55061             129.569000244, 44.5241012573
# 55062               122.43, 52.912777777799995
# 55063   123.91799926757812, 47.239601135253906
# 55064                    124.550178, 44.938114
# 55065             124.720222222, 52.2244444444
# 55066     121.53900146484375, 38.9656982421875
# 55067             125.703333333, 42.2538888889
# 55068   123.48300170898438, 41.639801025390625
# 55069             129.451004028, 42.8828010559
# 55070                      122.3586, 40.542524
# 55071   123.49600219726562, 41.784400939941406
# 55072                        1.4825, 51.894444
# 55073  47.296388888900005, -11.584277777799999
# 55074                    130.270556, 30.784722
#
# [54397 rows x 12 columns]

# %% [markdown]
# **Notes**:
# 1. 54397 rows out of 55075 contain NaN.

# %%
# NaN columns
airport.columns[airport.isna().any()]
# Out:
# Index(['elevation_ft', 'continent', 'iso_country', 'municipality', 'gps_code',
#        'iata_code', 'local_code'],
#       dtype='object')

# %% [markdown]
# **Notes**:
# 1. Some columns contain NaN values.

# %%
# mo duplicates
len(airport) == len(airport.drop_duplicates())
# Out:
# True

# %% [markdown]
# **Notes**:
# 1. There are no duplicates.

# %% [markdown]
# <a id="immigration"></a>

# %% [markdown]
# [Immigration](https://www.trade.gov/national-travel-and-tourism-office)

# %% [markdown]
# Use PySpark to load the full dataset.

# %%
# configure PySpark
spark = (SparkSession \
    .builder \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
    .getOrCreate())

# %%
# read the data 
immigration=spark.read.parquet("../sas_data/*.parquet")

# %%
# top 5
immigration.show(5)
# Out:
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# |    cicid| i94yr|i94mon|i94cit|i94res|i94port|arrdate|i94mode|i94addr|depdate|i94bir|i94visa|count|dtadfile|visapost|occup|entdepa|entdepd|entdepu|matflag|biryear| dtaddto|gender|insnum|airline|        admnum|fltno|visatype|
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# |5748517.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     CA|20582.0|  40.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1976.0|10292016|     F|  null|     QF|9.495387003E10|00011|      B1|
# |5748518.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     NV|20591.0|  32.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1984.0|10292016|     F|  null|     VA|9.495562283E10|00007|      B1|
# |5748519.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20582.0|  29.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1987.0|10292016|     M|  null|     DL|9.495640653E10|00040|      B1|
# |5748520.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20588.0|  29.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1987.0|10292016|     F|  null|     DL|9.495645143E10|00040|      B1|
# |5748521.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20588.0|  28.0|    1.0|  1.0|20160430|     SYD| null|      G|      O|   null|      M| 1988.0|10292016|     M|  null|     DL|9.495638813E10|00040|      B1|
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# only showing top 5 rows

# %%
# data type
immigration.printSchema()
# Out:
# root
#  |-- cicid: double (nullable = true)
#  |-- i94yr: double (nullable = true)
#  |-- i94mon: double (nullable = true)
#  |-- i94cit: double (nullable = true)
#  |-- i94res: double (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: double (nullable = true)
#  |-- i94mode: double (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: double (nullable = true)
#  |-- i94bir: double (nullable = true)
#  |-- i94visa: double (nullable = true)
#  |-- count: double (nullable = true)
#  |-- dtadfile: string (nullable = true)
#  |-- visapost: string (nullable = true)
#  |-- occup: string (nullable = true)
#  |-- entdepa: string (nullable = true)
#  |-- entdepd: string (nullable = true)
#  |-- entdepu: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: double (nullable = true)
#  |-- dtaddto: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- insnum: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- admnum: double (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
# duplicates
immigration.drop_duplicates().count() == immigration.count()
# Out:
# True

# %% [markdown]
# **Notes**:
# 1. "i94addr" contains "State" which could be a foreign key to link the above airport data.
# 2. Some columns contain "null" like "occup", "entdepu", "insnum".
# 3. Data formats need to be converted.
# 4. There are no duplicates.

# %% [markdown]
# <a id="city"></a>

# %% [markdown]
# [Cities](https://public.opendatasoft.com/explore/dataset/us-cities-demographics/export/)

# %%
# cities
# read data as "string" format to ensure all the information is correct and assign delimiter ";"
cities = pd.read_csv("../us-cities-demographics.csv", delimiter=";", dtype="str")

# %%
# top 5
cities.head()
# Out:
#                City          State Median Age Male Population  \
# 0     Silver Spring       Maryland       33.8           40601
# 1            Quincy  Massachusetts       41.0           44129
# 2            Hoover        Alabama       38.5           38040
# 3  Rancho Cucamonga     California       34.5           88127
# 4            Newark     New Jersey       34.6          138040
#
#   Female Population Total Population Number of Veterans Foreign-born  \
# 0             41862            82463               1562        30908
# 1             49500            93629               4147        32935
# 2             46799            84839               4819         8229
# 3             87105           175232               5821        33878
# 4            143873           281913               5829        86253
#
#   Average Household Size State Code                       Race  Count
# 0                    2.6         MD         Hispanic or Latino  25924
# 1                   2.39         MA                      White  58723
# 2                   2.58         AL                      Asian   4759
# 3                   3.18         CA  Black or African-American  24437
# 4                   2.73         NJ                      White  76402

# %% [markdown]
# **Notes**:
# 1. "State Code" can be used as a foreign key to join the above two tables.
# 2. Notice that "Race" and "Count" columns need to be transformed from long to wide so each race can be a separate column containing the population for that race.

# %%
# data information
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2891 entries, 0 to 2890
# Data columns (total 12 columns):
# City                      2891 non-null object
# State                     2891 non-null object
# Median Age                2891 non-null object
# Male Population           2888 non-null object
# Female Population         2888 non-null object
# Total Population          2891 non-null object
# Number of Veterans        2878 non-null object
# Foreign-born              2878 non-null object
# Average Household Size    2875 non-null object
# State Code                2891 non-null object
# Race                      2891 non-null object
# Count                     2891 non-null object
# dtypes: object(12)
# memory usage: 271.1+ KB

# %% [markdown]
# **Notes**:
# 1. All types are "object". Need to be changed to the right formats.

# %%
# unique information
cities.nunique()
# Out:
# City                       567
# State                       49
# Median Age                 180
# Male Population            593
# Female Population          594
# Total Population           594
# Number of Veterans         577
# Foreign-born               587
# Average Household Size     161
# State Code                  49
# Race                         5
# Count                     2785
# dtype: int64

# %%
# NaN rows
cities[cities.isnull().any(axis=1)]
# Out:
#               City        State Median Age Male Population Female Population  \
# 111       San Juan  Puerto Rico       41.4          155408            186829
# 155         Caguas  Puerto Rico       40.4           34743             42265
# 258       Carolina  Puerto Rico       42.0           64758             77308
# 333   The Villages      Florida       70.5             NaN               NaN
# 449   The Villages      Florida       70.5             NaN               NaN
# 637       Carolina  Puerto Rico       42.0           64758             77308
# 1437  The Villages      Florida       70.5             NaN               NaN
# 1747      San Juan  Puerto Rico       41.4          155408            186829
# 1748      Mayagüez  Puerto Rico       38.1           30799             35782
# 1995         Ponce  Puerto Rico       40.5           56968             64615
# 2004       Bayamón  Puerto Rico       39.4           80128             90131
# 2441      San Juan  Puerto Rico       41.4          155408            186829
# 2589      Guaynabo  Puerto Rico       42.2           33066             37426
# 2597        Caguas  Puerto Rico       40.4           34743             42265
# 2654      Guaynabo  Puerto Rico       42.2           33066             37426
# 2746      Mayagüez  Puerto Rico       38.1           30799             35782
#
#      Total Population Number of Veterans Foreign-born Average Household Size  \
# 111            342237                NaN          NaN                    NaN
# 155             77008                NaN          NaN                    NaN
# 258            142066                NaN          NaN                    NaN
# 333             72590              15231         4034                    NaN
# 449             72590              15231         4034                    NaN
# 637            142066                NaN          NaN                    NaN
# 1437            72590              15231         4034                    NaN
# 1747           342237                NaN          NaN                    NaN
# 1748            66581                NaN          NaN                    NaN
# 1995           121583                NaN          NaN                    NaN
# 2004           170259                NaN          NaN                    NaN
# 2441           342237                NaN          NaN                    NaN
# 2589            70492                NaN          NaN                    NaN
# 2597            77008                NaN          NaN                    NaN
# 2654            70492                NaN          NaN                    NaN
# 2746            66581                NaN          NaN                    NaN
#
#      State Code                               Race   Count
# 111          PR                 Hispanic or Latino  335559
# 155          PR                 Hispanic or Latino   76349
# 258          PR  American Indian and Alaska Native   12143
# 333          FL                 Hispanic or Latino    1066
# 449          FL          Black or African-American     331
# 637          PR                 Hispanic or Latino  139967
# 1437         FL                              White   72211
# 1747         PR  American Indian and Alaska Native    4031
# 1748         PR                              Asian     235
# 1995         PR                 Hispanic or Latino  120705
# 2004         PR                 Hispanic or Latino  169155
# 2441         PR                              Asian    2452
# 2589         PR                 Hispanic or Latino   69936
# 2597         PR  American Indian and Alaska Native     624
# 2654         PR  American Indian and Alaska Native     589
# 2746         PR                 Hispanic or Latino   65521

# %% [markdown]
# **Notes**:
# 1. 16 rows out of 2891 contain NaN, which could be dropped.

# %%
# NaN columns
cities.columns[cities.isna().any()]
# Out:
# Index(['Male Population', 'Female Population', 'Number of Veterans',
#        'Foreign-born', 'Average Household Size'],
#       dtype='object')

# %% [markdown]
# **Notes**:
# 1. Some columns contain NaN values.

# %%
# duplicates
len(cities) == len(cities.drop_duplicates())
# Out:
# True

# %% [markdown]
# **Notes**:
# 1. There are no duplicates.

# %% [markdown]
# <a id="temperature"></a>

# %% [markdown]
# [Temperature](https://www.kaggle.com/datasets/berkeleyearth/climate-change-earth-surface-temperature-data?resource=download)

# %%
# temperature
# read data as "string" format to ensure all the information is correct
temperature = pd.read_csv("../GlobalLandTemperaturesByState.csv", dtype="str")

# %%
# top 5
temperature.head()
# Out:
#            dt AverageTemperature AverageTemperatureUncertainty State Country
# 0  1855-05-01             25.544                         1.171  Acre  Brazil
# 1  1855-06-01             24.228                         1.103  Acre  Brazil
# 2  1855-07-01             24.371                         1.044  Acre  Brazil
# 3  1855-08-01             25.427                         1.073  Acre  Brazil
# 4  1855-09-01             25.675                         1.014  Acre  Brazil

# %% [markdown]
# **Notes**:
# 1. "State" contain the names of the states in each country, which could work as foreign key to join the above "cities" table and then get the "State Code" to join the other tables.

# %%
# data information
temperature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645675 entries, 0 to 645674
# Data columns (total 5 columns):
# dt                               645675 non-null object
# AverageTemperature               620027 non-null object
# AverageTemperatureUncertainty    620027 non-null object
# State                            645675 non-null object
# Country                          645675 non-null object
# dtypes: object(5)
# memory usage: 24.6+ MB

# %% [markdown]
# **Notes**:
# 1. All types are "object". Need to be changed to the right formats.

# %%
# statistics
temperature.describe()
# Out:
#                 dt AverageTemperature AverageTemperatureUncertainty    State  \
# count       645675             620027                        620027   645675
# unique        3239             100924                          8040      241
# top     1956-12-01             18.402                         0.255  Florida
# freq           241                 36                          1042     3239
#
#        Country
# count   645675
# unique       7
# top     Russia
# freq    254972

# %%
# unique values
temperature.nunique()
# Out:
# dt                                 3239
# AverageTemperature               100924
# AverageTemperatureUncertainty      8040
# State                               241
# Country                               7
# dtype: int64

# %%
# NaN rows
temperature[temperature.isnull().any(axis=1)]
# Out:
#                 dt AverageTemperature AverageTemperatureUncertainty     State  \
# 14      1856-07-01                NaN                           NaN      Acre
# 20      1857-01-01                NaN                           NaN      Acre
# 21      1857-02-01                NaN                           NaN      Acre
# 22      1857-03-01                NaN                           NaN      Acre
# 23      1857-04-01                NaN                           NaN      Acre
# 24      1857-05-01                NaN                           NaN      Acre
# 25      1857-06-01                NaN                           NaN      Acre
# 26      1857-07-01                NaN                           NaN      Acre
# 27      1857-08-01                NaN                           NaN      Acre
# 28      1857-09-01                NaN                           NaN      Acre
# 29      1857-10-01                NaN                           NaN      Acre
# 30      1857-11-01                NaN                           NaN      Acre
# 31      1857-12-01                NaN                           NaN      Acre
# 32      1858-01-01                NaN                           NaN      Acre
# 33      1858-02-01                NaN                           NaN      Acre
# 34      1858-03-01                NaN                           NaN      Acre
# 35      1858-04-01                NaN                           NaN      Acre
# 36      1858-05-01                NaN                           NaN      Acre
# 37      1858-06-01                NaN                           NaN      Acre
# 38      1858-07-01                NaN                           NaN      Acre
# 39      1858-08-01                NaN                           NaN      Acre
# 40      1858-09-01                NaN                           NaN      Acre
# 41      1858-10-01                NaN                           NaN      Acre
# 42      1858-11-01                NaN                           NaN      Acre
# 43      1858-12-01                NaN                           NaN      Acre
# 44      1859-01-01                NaN                           NaN      Acre
# 45      1859-02-01                NaN                           NaN      Acre
# 46      1859-03-01                NaN                           NaN      Acre
# 47      1859-04-01                NaN                           NaN      Acre
# 48      1859-05-01                NaN                           NaN      Acre
# ...            ...                ...                           ...       ...
# 641495  1838-03-01                NaN                           NaN    Yunnan
# 641497  1838-05-01                NaN                           NaN    Yunnan
# 641504  1838-12-01                NaN                           NaN    Yunnan
# 641505  1839-01-01                NaN                           NaN    Yunnan
# 641506  1839-02-01                NaN                           NaN    Yunnan
# 641507  1839-03-01                NaN                           NaN    Yunnan
# 641508  1839-04-01                NaN                           NaN    Yunnan
# 641509  1839-05-01                NaN                           NaN    Yunnan
# 641510  1839-06-01                NaN                           NaN    Yunnan
# 641511  1839-07-01                NaN                           NaN    Yunnan
# 641512  1839-08-01                NaN                           NaN    Yunnan
# 641513  1839-09-01                NaN                           NaN    Yunnan
# 641514  1839-10-01                NaN                           NaN    Yunnan
# 641515  1839-11-01                NaN                           NaN    Yunnan
# 641516  1839-12-01                NaN                           NaN    Yunnan
# 641648  1850-12-01                NaN                           NaN    Yunnan
# 641651  1851-03-01                NaN                           NaN    Yunnan
# 641731  1857-11-01                NaN                           NaN    Yunnan
# 641732  1857-12-01                NaN                           NaN    Yunnan
# 641784  1862-04-01                NaN                           NaN    Yunnan
# 641785  1862-05-01                NaN                           NaN    Yunnan
# 641786  1862-06-01                NaN                           NaN    Yunnan
# 641787  1862-07-01                NaN                           NaN    Yunnan
# 641788  1862-08-01                NaN                           NaN    Yunnan
# 641789  1862-09-01                NaN                           NaN    Yunnan
# 641790  1862-10-01                NaN                           NaN    Yunnan
# 641791  1862-11-01                NaN                           NaN    Yunnan
# 641792  1862-12-01                NaN                           NaN    Yunnan
# 643601  2013-09-01                NaN                           NaN    Yunnan
# 645674  2013-09-01                NaN                           NaN  Zhejiang
#
#        Country
# 14      Brazil
# 20      Brazil
# 21      Brazil
# 22      Brazil
# 23      Brazil
# 24      Brazil
# 25      Brazil
# 26      Brazil
# 27      Brazil
# 28      Brazil
# 29      Brazil
# 30      Brazil
# 31      Brazil
# 32      Brazil
# 33      Brazil
# 34      Brazil
# 35      Brazil
# 36      Brazil
# 37      Brazil
# 38      Brazil
# 39      Brazil
# 40      Brazil
# 41      Brazil
# 42      Brazil
# 43      Brazil
# 44      Brazil
# 45      Brazil
# 46      Brazil
# 47      Brazil
# 48      Brazil
# ...        ...
# 641495   China
# 641497   China
# 641504   China
# 641505   China
# 641506   China
# 641507   China
# 641508   China
# 641509   China
# 641510   China
# 641511   China
# 641512   China
# 641513   China
# 641514   China
# 641515   China
# 641516   China
# 641648   China
# 641651   China
# 641731   China
# 641732   China
# 641784   China
# 641785   China
# 641786   China
# 641787   China
# 641788   China
# 641789   China
# 641790   China
# 641791   China
# 641792   China
# 643601   China
# 645674   China
#
# [25648 rows x 5 columns]

# %% [markdown]
# **Notes**:
# 1. 25648 rows out of 645675 contain NaN.

# %%
# NaN columns
temperature.columns[temperature.isna().any()]
# Out:
# Index(['AverageTemperature', 'AverageTemperatureUncertainty'], dtype='object')

# %% [markdown]
# **Notes**:
# 1. Some columns contain NaN values.

# %%
# duplicates
len(temperature) == len(temperature.drop_duplicates())
# Out:
# True

# %% [markdown]
# **Notes**:
# 1. There are no duplicates.

# %% [markdown]
# <a id="clean"></a>

# %% [markdown]
# #### 2.2 Clean Steps

# %% [markdown]
# ##### airport
# 1. to numeric "elevation_ft"
# 2. Separate "iso_region" to two columns
# 3. Separate "coordinates" to two columns and round
# 4. Drop other airport type only keeping "airport" & not closed
# 5. Only include US

# %%
# US airport 
airportUS = (airport.loc[(airport.iso_country == "US") 
                         & ~(airport.type == "closed") 
                         & airport.type.str.contains("airport")])

# %%
# change "elevation_ft" to numeric
airportUS["elevation_ft"] = airportUS["elevation_ft"].astype(float)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# separate "iso_region" to "country" and "region"
airportUS[["country", "region"]] = airportUS["iso_region"].str.split("-", 1, expand = True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
# separate "iso_region" to "country" and "region" and round 4
airportUS[["longitude", "latitude"]] = airportUS["coordinates"].str.split(",", 1, expand = True).astype(float).round(4)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
# drop unnecessary columns 
airportUSNew = (airportUS.drop(["iso_country", "iso_region", "coordinates", "country", 
                                "continent","iata_code", "gps_code", "local_code", "municipality"], 
                               axis=1))

# %%
# NaN rows
airportUSNew[airportUSNew.isnull().any(axis=1)]
# Out:
#          ident            type  \
# 6875      63CA   small_airport
# 6981      65LA   small_airport
# 7653      6XA4   small_airport
# 9006      8AL3   small_airport
# 9910      9CL9   small_airport
# 12375     BOBS   small_airport
# 12378     BONI   small_airport
# 12788     BUTL   small_airport
# 14544     CHAN   small_airport
# 15740     CRAI   small_airport
# 22637     GOAD   small_airport
# 23109     HOPA   small_airport
# 24946     JAMI   small_airport
# 24982     JOEY   small_airport
# 28633     KPRS   small_airport
# 38029     OVER   small_airport
# 38388     PAUT   small_airport
# 39070     POSG   small_airport
# 40095     RSCO   small_airport
# 47563     TA37   small_airport
# 49015  US-0001   small_airport
# 49023  US-0009   small_airport
# 49025  US-0011   small_airport
# 49069  US-0055   small_airport
# 49070  US-0056   small_airport
# 49073  US-0059   small_airport
# 49177  US-0163   small_airport
# 49191  US-0177   small_airport
# 49214  US-0200   small_airport
# 49215  US-0201   small_airport
# ...        ...             ...
# 49267  US-0253   small_airport
# 49268  US-0254  medium_airport
# 49272  US-0258   small_airport
# 49273  US-0259   small_airport
# 49282  US-0268   small_airport
# 49299  US-0285   small_airport
# 49300  US-0286   small_airport
# 49301  US-0287   small_airport
# 49318  US-0303   large_airport
# 49372  US-0357   small_airport
# 49386  US-0371   small_airport
# 49387  US-0372   small_airport
# 49388  US-0373   small_airport
# 49389  US-0374   small_airport
# 49469  US-0454   small_airport
# 49475  US-0460   small_airport
# 49480  US-0465   small_airport
# 49481  US-0466   small_airport
# 49694  US-0679   small_airport
# 49757  US-0742  medium_airport
# 49758  US-0743   small_airport
# 49820  US-0805   small_airport
# 49893  US-0878   small_airport
# 49894  US-0879  medium_airport
# 49898  US-0883   large_airport
# 49947  US-0932   small_airport
# 49969  US-0954   small_airport
# 49999  US-0984   small_airport
# 50032  US-1016   large_airport
# 51887     WEON   small_airport
#
#                                                     name  elevation_ft region  \
# 6875                        Desert Air Sky Ranch Airport           NaN     CA
# 6981                           Southern Seaplane Airport           NaN     LA
# 7653                                      Zadow Airstrip           NaN     TX
# 9006                                Fricks Field Airport           NaN     AL
# 9910                                      Spezia Airport           NaN     CA
# 12375                                               Bobs           NaN     AR
# 12378                                             Bonita           NaN     LA
# 12788                                  Butlerville Field           NaN     AR
# 14544                              A & C AG Aviation Inc           NaN     GA
# 15740                                      Craig's field           NaN     LA
# 22637                                        Goads field           NaN     AR
# 23109                                     Hoppe Airspray           NaN     IA
# 24946                                             Jamies           NaN     AR
# 24982                                              Joeys           NaN     AR
# 28633                Presidio Lely International Airport           NaN     TX
# 38029                                     Overturf Field           NaN     AR
# 38388                                       Akun Airport           NaN     AK
# 39070                                  Possum Grape Exit           NaN     AR
# 40095                                       Scotts Field           NaN     AR
# 47563                                   Vaca Moo Airport           NaN     TX
# 49015                            Flying M Ranch Airstrip           NaN     NV
# 49023                                 Ski Valley Airport           NaN     ID
# 49025                    Cascade Reservoir Private Strip           NaN     ID
# 49069                                  Alaki Hot Springs           NaN     NV
# 49070                                        Delle, Utah           NaN     UT
# 49073                                      Chicken Strip           NaN     CA
# 49177                          Panamint Springs Airstrip           NaN     CA
# 49191                                        Utley Field           NaN     TX
# 49214                                        Kogru River           NaN     AK
# 49215                                       Cape Simpson           NaN     AK
# ...                                                  ...           ...    ...
# 49267                             Collensville/twincreek           NaN     AK
# 49268                              Yuma Auxiliary AAF #2           NaN     AZ
# 49272                           Austin Executive Airport           NaN     TX
# 49273                               Snyder Winston Field           NaN     TX
# 49282                     Gardiners Island Landing Field           NaN     NY
# 49299                        Private strip nr Huntsville           NaN     TX
# 49300                                    Hodges Airfield           NaN     LA
# 49301              Forest service strip nr Kurthwood, LA           NaN     LA
# 49318                                                atl           NaN    U-A
# 49372                                     Reynolds Field           NaN     AR
# 49386                                        Bells Field           NaN     AR
# 49387                                        Stans Field           NaN     AR
# 49388                                      Mallets Field           NaN     AR
# 49389                                      Lesters Field           NaN     AR
# 49469                                Pumpkin Patch Field           NaN     AR
# 49475                                       Falwell Base           NaN     AR
# 49480                                    Falwell Freeway           NaN     AR
# 49481                                  Schroeder's field           NaN     AR
# 49694                                  Entz Arts Airport           NaN     OK
# 49757                                        34S Airport           NaN    U-A
# 49758                                        23R Airport           NaN     CA
# 49820                                        Twin Cities           NaN    U-A
# 49893  Buy Generic Cytotec Online Without A Prescript...           NaN     NY
# 49894  Buy Lyrica online (Pregabalin) 150mg capsules ...           NaN    U-A
# 49898                                                JFK           NaN     NY
# 49947                                                CLE           NaN    U-A
# 49969                   Dulpicate - Shelter Cove Airport           NaN     CA
# 49999                                                0c2           NaN     IL
# 50032                                                JFK           NaN     NY
# 51887                                              Weona           NaN     AR
#
#        longitude  latitude
# 6875   -115.8740   33.4811
# 6981    -90.0222   29.8661
# 7653    -95.9544   29.9917
# 9006    -86.0886   34.1418
# 9910   -121.5340   38.2166
# 12375   -91.4437   35.3915
# 12378   -91.7114   32.8944
# 12788   -91.8312   34.9697
# 14544   -83.6929   32.1711
# 15740   -91.9192   30.4962
# 22637   -91.4025   35.4142
# 23109   -92.8355   42.2570
# 24946   -90.7291   35.5205
# 24982   -91.3483   35.3985
# 28633  -104.3615   29.6342
# 38029   -91.9781   34.9977
# 38388  -165.6076   54.1450
# 39070   -91.3980   35.4582
# 40095   -90.8002   36.0143
# 47563   -95.7126   32.4280
# 49015  -118.9960   38.6094
# 49023  -116.1740   44.9291
# 49025  -116.0870   44.6474
# 49069  -118.0733   37.6750
# 49070  -112.7873   40.7626
# 49073  -117.7817   36.8070
# 49177  -117.4671   36.3383
# 49191   -97.4060   30.1827
# 49214  -152.2597   70.5740
# 49215  -154.7365   71.0580
# ...          ...       ...
# 49267  -151.4754   62.3394
# 49268  -114.5114   32.5490
# 49272   -97.5664   30.3975
# 49273  -100.9500   32.6900
# 49282   -72.0922   41.0652
# 49299   -95.5422   30.7985
# 49300   -93.3951   31.3736
# 49301   -93.1574   31.3165
# 49318   -84.3750   33.1376
# 49372   -91.0685   35.1894
# 49386   -91.5460   34.9802
# 49387   -91.2572   34.9897
# 49388   -92.5350   35.2111
# 49389   -91.3411   35.2773
# 49469   -92.2178   34.6368
# 49475   -91.3330   35.5491
# 49480   -91.3625   35.4650
# 49481   -91.7388   35.0717
# 49694     0.0000   35.4499
# 49757   -16.8750   19.1452
# 49758     8.4375   11.5231
# 49820     0.0000    0.0000
# 49893     3.0000    1.0000
# 49894     3.1667   -1.1667
# 49898     0.0000    0.0000
# 49947     0.0000    0.0000
# 49969   124.0711   40.0289
# 49999     0.0000    0.0000
# 50032     0.0000    0.0000
# 51887   -90.5965   35.5404
#
# [63 rows x 7 columns]

# %%
# len(airportUSNew) ## 14582

# %% [markdown]
# Only 63 rows out of 14582 rows contain NaN, which could be dropped.

# %%
# drop NaN
airportUSNewNoNa = airportUSNew.dropna()

# %%
# NaN rows
#airportUSNewNoNa[airportUSNewNoNa.isnull().any(axis=1)]

# %%
# duplicates
len(airportUSNewNoNa) == len(airportUSNewNoNa.drop_duplicates())
# Out:
# True

# %%
# data information
airportUSNewNoNa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14519 entries, 1 to 54896
# Data columns (total 7 columns):
# ident           14519 non-null object
# type            14519 non-null object
# name            14519 non-null object
# elevation_ft    14519 non-null float64
# region          14519 non-null object
# longitude       14519 non-null float64
# latitude        14519 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 907.4+ KB

# %%
# top 5
airportUSNewNoNa.head()
# Out:
#   ident           type                  name  elevation_ft region  longitude  \
# 1  00AA  small_airport  Aero B Ranch Airport        3435.0     KS  -101.4739
# 2  00AK  small_airport          Lowell Field         450.0     AK  -151.6960
# 3  00AL  small_airport          Epps Airpark         820.0     AL   -86.7703
# 5  00AS  small_airport        Fulton Airport        1100.0     OK   -97.8180
# 6  00AZ  small_airport        Cordes Airport        3810.0     AZ  -112.1650
#
#    latitude
# 1   38.7040
# 2   59.9492
# 3   34.8648
# 5   34.9428
# 6   34.3056

# %%
# save it as a csv and remove header and index and move it to aws s3 
airportUSNewNoNa.to_csv("airportUS.csv", sep=",", header=False, index=False, encoding="utf-8")
s3 = boto3.resource('s3')
s3.meta.client.upload_file('airportUS.csv', 'udacity-capstone-project-bucket-test', 'airportUS.csv')

# %% [markdown]
# ##### cities
# 1. Transform columns "Race" and "Count" from long to wide
# 2. To numeric: "Male Population", "Female Population", "Total Population", "Number of Veterans", "Foreign-born", "Count"
# 3. To float: "Median Age", "Average Household Size"

# %%
# NaN rows
cities[cities.isnull().any(axis=1)]
# Out:
#               City        State Median Age Male Population Female Population  \
# 111       San Juan  Puerto Rico       41.4          155408            186829
# 155         Caguas  Puerto Rico       40.4           34743             42265
# 258       Carolina  Puerto Rico       42.0           64758             77308
# 333   The Villages      Florida       70.5             NaN               NaN
# 449   The Villages      Florida       70.5             NaN               NaN
# 637       Carolina  Puerto Rico       42.0           64758             77308
# 1437  The Villages      Florida       70.5             NaN               NaN
# 1747      San Juan  Puerto Rico       41.4          155408            186829
# 1748      Mayagüez  Puerto Rico       38.1           30799             35782
# 1995         Ponce  Puerto Rico       40.5           56968             64615
# 2004       Bayamón  Puerto Rico       39.4           80128             90131
# 2441      San Juan  Puerto Rico       41.4          155408            186829
# 2589      Guaynabo  Puerto Rico       42.2           33066             37426
# 2597        Caguas  Puerto Rico       40.4           34743             42265
# 2654      Guaynabo  Puerto Rico       42.2           33066             37426
# 2746      Mayagüez  Puerto Rico       38.1           30799             35782
#
#      Total Population Number of Veterans Foreign-born Average Household Size  \
# 111            342237                NaN          NaN                    NaN
# 155             77008                NaN          NaN                    NaN
# 258            142066                NaN          NaN                    NaN
# 333             72590              15231         4034                    NaN
# 449             72590              15231         4034                    NaN
# 637            142066                NaN          NaN                    NaN
# 1437            72590              15231         4034                    NaN
# 1747           342237                NaN          NaN                    NaN
# 1748            66581                NaN          NaN                    NaN
# 1995           121583                NaN          NaN                    NaN
# 2004           170259                NaN          NaN                    NaN
# 2441           342237                NaN          NaN                    NaN
# 2589            70492                NaN          NaN                    NaN
# 2597            77008                NaN          NaN                    NaN
# 2654            70492                NaN          NaN                    NaN
# 2746            66581                NaN          NaN                    NaN
#
#      State Code                               Race   Count
# 111          PR                 Hispanic or Latino  335559
# 155          PR                 Hispanic or Latino   76349
# 258          PR  American Indian and Alaska Native   12143
# 333          FL                 Hispanic or Latino    1066
# 449          FL          Black or African-American     331
# 637          PR                 Hispanic or Latino  139967
# 1437         FL                              White   72211
# 1747         PR  American Indian and Alaska Native    4031
# 1748         PR                              Asian     235
# 1995         PR                 Hispanic or Latino  120705
# 2004         PR                 Hispanic or Latino  169155
# 2441         PR                              Asian    2452
# 2589         PR                 Hispanic or Latino   69936
# 2597         PR  American Indian and Alaska Native     624
# 2654         PR  American Indian and Alaska Native     589
# 2746         PR                 Hispanic or Latino   65521

# %%
# len(cities[cities.isnull().any(axis=1)]) ## 16 rows are blank

# %%
# len(cities) ## 2891

# %% [markdown]
# 16 rows out of 2891 are blank. And the status are "Puerto Rico" and "Florida (The Villages)". Thus, dropped these places.

# %%
# drop NaN
citiesNoNa = cities.dropna()

# %%
# change "Count" to "float" before converting, otherwise showing errors
citiesNoNa["Count"] = citiesNoNa["Count"].astype(float)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# transform from long to wide
citiesPop = citiesNoNa[['City', 'State', 'Median Age', 'Male Population',
       'Female Population', 'Total Population', 'Number of Veterans',
       'Foreign-born', 'Average Household Size', 'State Code']]
citiesRace = (pd.pivot_table(citiesNoNa[["City", "Race", "Count"]], 
                             index="City", columns = "Race", values= "Count")
                          .reset_index().reset_index(drop=True).rename_axis(None, axis=1))
citiesNew = citiesPop.merge(citiesRace, on="City", how="left")

# %%
# citiesNew.head()

# %%
# to integer 
citiesNew[["Male Population", "Female Population", 
           "Total Population", "Number of Veterans", "Foreign-born"]] = (citiesNew[["Male Population", "Female Population", 
                                                        "Total Population", "Number of Veterans", "Foreign-born"
                                                        ]].astype(int))

# %%
# to float since some rows contain NaN
# show errors if converting to int
citiesNew[["American Indian and Alaska Native", "Asian", 
           "Black or African-American", "Hispanic or Latino", "White"]] = (citiesNew[["American Indian and Alaska Native", "Asian", 
                                                                                      "Black or African-American", "Hispanic or Latino", "White"]].astype(float))

# %%
# to float
citiesNew[["Median Age", "Average Household Size"]] = (citiesNew[["Median Age", "Average Household Size"]].astype(float))

# %%
# NaN rows
citiesNew[citiesNew.isnull().any(axis=1)]
# Out:
#                    City           State  Median Age  Male Population  \
# 2                Hoover         Alabama        38.5            38040
# 15           Fort Myers         Florida        37.3            36850
# 35        Miami Gardens         Florida        34.9            50719
# 38    North Little Rock        Arkansas        33.6            31671
# 44          New Britain     Connecticut        33.4            37350
# 49               Camden      New Jersey        27.9            36437
# 71              Lynwood      California        29.4            35634
# 134             Alafaya         Florida        33.5            39504
# 138         Miami Beach         Florida        42.5            48090
# 156           Champaign        Illinois        28.7            43326
# 177             Miramar         Florida        36.6            66157
# 179   Arlington Heights        Illinois        45.9            37627
# 186    Sterling Heights        Michigan        39.6            64985
# 201            Edinburg           Texas        29.3            39422
# 206           Bethlehem    Pennsylvania        35.1            35861
# 213               Vista      California        29.3            50680
# 227             Fishers         Indiana        34.5            42161
# 231            Victoria           Texas        35.8            32290
# 232            Victoria           Texas        35.8            32290
# 242            Gulfport     Mississippi        35.1            33108
# 259                Ames            Iowa        23.0            33814
# 296           Kissimmee         Florida        36.7            33283
# 324             Bayonne      New Jersey        39.7            32705
# 357          Plantation         Florida        40.6            42881
# 363   North Little Rock        Arkansas        33.6            31671
# 372             Lynwood      California        29.4            35634
# 389             Kendall         Florida        40.2            36658
# 393        Walnut Creek      California        47.6            31994
# 394             Mission           Texas        32.9            40530
# 397         Cheektowaga        New York        40.7            37476
# ...                 ...             ...         ...              ...
# 2461            Sunrise         Florida        37.7            41471
# 2473      Laguna Niguel      California        45.8            30193
# 2493   Sterling Heights        Michigan        39.6            64985
# 2505            Kendall         Florida        40.2            36658
# 2529              Pharr           Texas        26.9            35242
# 2541            Hialeah         Florida        43.0           111530
# 2543           Scranton    Pennsylvania        38.5            37975
# 2564             Canton            Ohio        33.4            34476
# 2572             Muncie         Indiana        27.4            32446
# 2602           Woodbury       Minnesota        37.7            31982
# 2623        League City           Texas        35.9            49354
# 2631        Miami Beach         Florida        42.5            48090
# 2648       South Jordan            Utah        33.8            33669
# 2668        League City           Texas        35.9            49354
# 2690         Pine Hills         Florida        29.2            35344
# 2713    Florence-Graham      California        30.2            34186
# 2716            Warwick    Rhode Island        42.6            39289
# 2730            Fishers         Indiana        34.5            42161
# 2735     Mount Pleasant  South Carolina        42.7            39429
# 2761           Franklin       Tennessee        38.3            34991
# 2767              Vista      California        29.3            50680
# 2772         Sugar Land           Texas        42.1            43889
# 2780           Franklin       Tennessee        38.3            34991
# 2785             Carmel         Indiana        39.9            42928
# 2790           Franklin       Tennessee        38.3            34991
# 2825            Passaic      New Jersey        30.4            36505
# 2826     Mount Pleasant  South Carolina        42.7            39429
# 2845           Scranton    Pennsylvania        38.5            37975
# 2857             Carmel         Indiana        39.9            42928
# 2865           Gulfport     Mississippi        35.1            33108
#
#       Female Population  Total Population  Number of Veterans  Foreign-born  \
# 2                 46799             84839                4819          8229
# 15                37165             74015                4312         15365
# 35                62480            113199                2327         33394
# 38                34835             66506                4130          2787
# 44                35459             72809                2219         15080
# 49                39694             76131                1425         11317
# 71                36371             72005                 776         28061
# 134               45760             85264                4176         15842
# 138               44221             92311                2265         49908
# 156               42760             86086                3734         12261
# 177               70958            137115                3077         57179
# 179               39369             76996                3027         14630
# 186               67077            132062                6970         34313
# 201               45079             84501                2409         16569
# 206               38506             74367                4704          6295
# 213               50204            100884                4957         23271
# 227               43910             86071                2469          6138
# 231               35291             67581                5000          4480
# 232               35291             67581                5000          4480
# 242               38764             71872                6646          3072
# 259               31238             65052                2265          8606
# 296               35869             69152                2449         16879
# 324               33598             66303                2225         21899
# 357               49674             92555                4037         27902
# 363               34835             66506                4130          2787
# 372               36371             72005                 776         28061
# 389               39808             76466                1678         31180
# 393               36912             68906                4977         13624
# 394               42777             83307                2383         22608
# 397               38599             76075                5408          3532
# ...                 ...               ...                 ...           ...
# 2461              51235             92706                4108         38209
# 2473              35619             65812                2648         12571
# 2493              67077            132062                6970         34313
# 2505              39808             76466                1678         31180
# 2529              41293             76535                1376         25532
# 2541             125552            237082                1844        170148
# 2543              39137             77112                5059          8069
# 2564              37419             71895                3404          2204
# 2572              37255             69701                2968          1062
# 2602              35868             67850                2732          9477
# 2623              48996             98350                6484          8361
# 2631              44221             92311                2265         49908
# 2648              32970             66639                2595          6142
# 2668              48996             98350                6484          8361
# 2690              40737             76081                2594         20735
# 2713              32173             66359                 416         28696
# 2716              42409             81698                5799          5318
# 2730              43910             86071                2469          6138
# 2735              41880             81309                3981          4701
# 2761              37644             72635                3303          6876
# 2767              50204            100884                4957         23271
# 2772              44240             88129                4377         31169
# 2780              37644             72635                3303          6876
# 2785              46101             89029                2723          9645
# 2790              37644             72635                3303          6876
# 2825              34577             71082                 693         24174
# 2826              41880             81309                3981          4701
# 2845              39137             77112                5059          8069
# 2857              46101             89029                2723          9645
# 2865              38764             71872                6646          3072
#
#       Average Household Size State Code  American Indian and Alaska Native  \
# 2                       2.58         AL                                NaN
# 15                      2.45         FL                                NaN
# 35                      3.75         FL                                NaN
# 38                      2.62         AR                              713.0
# 44                      2.52         CT                                NaN
# 49                      3.00         NJ                                NaN
# 71                      4.43         CA                                NaN
# 134                     2.94         FL                                NaN
# 138                     2.10         FL                                NaN
# 156                     2.25         IL                                NaN
# 177                     3.41         FL                                NaN
# 179                     2.38         IL                                NaN
# 186                     2.66         MI                                NaN
# 201                     3.31         TX                                NaN
# 206                     2.46         PA                                NaN
# 213                     3.52         CA                                NaN
# 227                     2.80         IN                                NaN
# 231                     2.70         TX                                NaN
# 232                     2.70         TX                                NaN
# 242                     2.54         MS                                NaN
# 259                     2.16         IA                                NaN
# 296                     3.01         FL                                NaN
# 324                     2.62         NJ                                NaN
# 357                     2.73         FL                                NaN
# 363                     2.62         AR                              713.0
# 372                     4.43         CA                                NaN
# 389                     2.81         FL                                NaN
# 393                     2.22         CA                                NaN
# 394                     3.51         TX                                NaN
# 397                     2.30         NY                                NaN
# ...                      ...        ...                                ...
# 2461                    2.98         FL                                NaN
# 2473                    2.58         CA                                NaN
# 2493                    2.66         MI                                NaN
# 2505                    2.81         FL                                NaN
# 2529                    3.67         TX                                NaN
# 2541                    3.31         FL                                NaN
# 2543                    2.39         PA                                NaN
# 2564                    2.32         OH                              358.0
# 2572                    2.35         IN                              203.0
# 2602                    2.72         MN                                NaN
# 2623                    2.72         TX                                NaN
# 2631                    2.10         FL                                NaN
# 2648                    3.61         UT                                NaN
# 2668                    2.72         TX                                NaN
# 2690                    3.30         FL                                NaN
# 2713                    4.57         CA                                NaN
# 2716                    2.40         RI                                NaN
# 2730                    2.80         IN                                NaN
# 2735                    2.53         SC                                NaN
# 2761                    2.73         TN                                NaN
# 2767                    3.52         CA                                NaN
# 2772                    2.95         TX                                NaN
# 2780                    2.73         TN                                NaN
# 2785                    2.71         IN                                NaN
# 2790                    2.73         TN                                NaN
# 2825                    3.56         NJ                                NaN
# 2826                    2.53         SC                                NaN
# 2845                    2.39         PA                                NaN
# 2857                    2.71         IN                                NaN
# 2865                    2.54         MS                                NaN
#
#         Asian  Black or African-American  Hispanic or Latino     White
# 2      4759.0                    18191.0              3430.0   61869.0
# 15     3519.0                    17298.0             17866.0   50169.0
# 35        NaN                    85300.0             23287.0   27273.0
# 38        NaN                    30766.0              4860.0   34118.0
# 44     2297.0                     9873.0             30188.0   56431.0
# 49     1686.0                    35237.0             41473.0   19907.0
# 71      994.0                     5346.0             63377.0   48670.0
# 134   10336.0                     6577.0             34897.0   63666.0
# 138    2772.0                     4013.0             47446.0   72180.0
# 156   11746.0                    16163.0              4015.0   58099.0
# 177   12084.0                    65840.0             46767.0   58914.0
# 179    9975.0                     1222.0              2742.0   66285.0
# 186   12264.0                     8054.0              2811.0  112743.0
# 201     812.0                        NaN             74698.0   77560.0
# 206    3759.0                     7821.0             23409.0   64526.0
# 213    7189.0                     5164.0             49524.0   83529.0
# 227    7571.0                     6873.0              3409.0   73361.0
# 231    2032.0                     6058.0             34409.0   58798.0
# 232    2032.0                     6058.0             34409.0   58798.0
# 242    1723.0                    27799.0              4247.0   42870.0
# 259    8979.0                     1103.0              2024.0   56157.0
# 296    2634.0                     6623.0             44120.0   51123.0
# 324    7171.0                     7581.0             19525.0   41431.0
# 357    3954.0                    19670.0             26401.0   66970.0
# 363       NaN                    30766.0              4860.0   34118.0
# 372     994.0                     5346.0             63377.0   48670.0
# 389    3650.0                     2937.0             47521.0   70266.0
# 393   10831.0                     1705.0              5212.0   57064.0
# 394    3075.0                        NaN             73367.0   77985.0
# 397    1584.0                    10562.0              1994.0   63541.0
# ...       ...                        ...                 ...       ...
# 2461   3501.0                    33951.0             29163.0   54976.0
# 2473   8499.0                      881.0              9203.0   55919.0
# 2493  12264.0                     8054.0              2811.0  112743.0
# 2505   3650.0                     2937.0             47521.0   70266.0
# 2529      NaN                      204.0             72995.0   73694.0
# 2541   1149.0                     5687.0            227508.0  219991.0
# 2543   4722.0                     6256.0             11301.0   66875.0
# 2564      NaN                    21353.0              3597.0   53571.0
# 2572      NaN                    10482.0              2499.0   59962.0
# 2602   7758.0                     6054.0              3258.0   56216.0
# 2623   8163.0                     4166.0             14868.0   86012.0
# 2631   2772.0                     4013.0             47446.0   72180.0
# 2648   2487.0                        NaN              4672.0   59046.0
# 2668   8163.0                     4166.0             14868.0   86012.0
# 2690   2209.0                    57089.0             10496.0   10029.0
# 2713      NaN                     5060.0             60895.0   30591.0
# 2716   2685.0                     1212.0              4723.0   76999.0
# 2730   7571.0                     6873.0              3409.0   73361.0
# 2735   1827.0                     3730.0              2569.0   75908.0
# 2761   3911.0                     7749.0              4916.0   61459.0
# 2767   7189.0                     5164.0             49524.0   83529.0
# 2772  33469.0                     8993.0              7835.0   44555.0
# 2780   3911.0                     7749.0              4916.0   61459.0
# 2785  11223.0                     2171.0              3111.0   77178.0
# 2790   3911.0                     7749.0              4916.0   61459.0
# 2825   3338.0                     5230.0             53680.0   30352.0
# 2826   1827.0                     3730.0              2569.0   75908.0
# 2845   4722.0                     6256.0             11301.0   66875.0
# 2857  11223.0                     2171.0              3111.0   77178.0
# 2865   1723.0                    27799.0              4247.0   42870.0
#
# [212 rows x 15 columns]

# %%
# len(citiesNew) ## 2875

# %% [markdown]
# 212 rows out of 2875 contain NaN which are related to "American Indian and Alaska Native". Thus, don't dropped.

# %%
# duplicates
len(citiesNew) == len(citiesNew.drop_duplicates())
# Out:
# False

# %%
#len(citiesNew.drop_duplicates()) ## 588

# %%
# drop duplicates
citiesNewNoDup = citiesNew.drop_duplicates()

# %%
# data information
citiesNewNoDup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588 entries, 0 to 2711
# Data columns (total 15 columns):
# City                                 588 non-null object
# State                                588 non-null object
# Median Age                           588 non-null float64
# Male Population                      588 non-null int64
# Female Population                    588 non-null int64
# Total Population                     588 non-null int64
# Number of Veterans                   588 non-null int64
# Foreign-born                         588 non-null int64
# Average Household Size               588 non-null float64
# State Code                           588 non-null object
# American Indian and Alaska Native    537 non-null float64
# Asian                                581 non-null float64
# Black or African-American            583 non-null float64
# Hispanic or Latino                   588 non-null float64
# White                                588 non-null float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 73.5+ KB

# %%
# top 5
citiesNewNoDup.head()
# Out:
#                City          State  Median Age  Male Population  \
# 0     Silver Spring       Maryland        33.8            40601
# 1            Quincy  Massachusetts        41.0            44129
# 2            Hoover        Alabama        38.5            38040
# 3  Rancho Cucamonga     California        34.5            88127
# 4            Newark     New Jersey        34.6           138040
#
#    Female Population  Total Population  Number of Veterans  Foreign-born  \
# 0              41862             82463                1562         30908
# 1              49500             93629                4147         32935
# 2              46799             84839                4819          8229
# 3              87105            175232                5821         33878
# 4             143873            281913                5829         86253
#
#    Average Household Size State Code  American Indian and Alaska Native  \
# 0                    2.60         MD                             1084.0
# 1                    2.39         MA                              351.0
# 2                    2.58         AL                                NaN
# 3                    3.18         CA                             2789.0
# 4                    2.73         NJ                             2268.0
#
#      Asian  Black or African-American  Hispanic or Latino     White
# 0   8841.0                    21330.0             25924.0   37756.0
# 1  30473.0                     3917.0              2566.0   58723.0
# 2   4759.0                    18191.0              3430.0   61869.0
# 3  24519.0                    24437.0             65823.0  111832.0
# 4   7349.0                   144961.0            100432.0   76402.0

# %%
# save it as a csv and remove header and index and move it to aws s3 
citiesNewNoDup.to_csv("citiesUS.csv", sep=",", header=False, index=False, encoding="utf-8")
s3 = boto3.resource('s3')
s3.meta.client.upload_file('citiesUS.csv', 'udacity-capstone-project-bucket-test', 'citiesUS.csv')

# %% [markdown]
# ##### immigration
# 1. to date "arrdate", "depdate", "dtadfile"
# 2. to text "cicid", "i94cit", "i94res", "admnum"
# 3. to integer "i94yr", "i94mon", "i94mode", "i94bir", "	i94visa", "count"

# %% [markdown]
# Most of the NaN values are existent in "visapost", "occup", "entdepu", "insnum" columns which are not necessary for data analysis.

# %%
# drop unnecessary columns
immigrationNew = immigration.drop("visapost", "occup", "entdepu", "insnum")

# %%
# immigrationNew.show(5)

# %%
# 13 rows out of 1000 contain "D/S" value for "dtaddto"
# needs to be dropped, then can change to date format
immigrationNew.filter(immigrationNew.dtaddto == "D/S").show(5)
# Out:
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+-------+-------+-------+-------+-------+------+-------+--------------+-----+--------+
# |    cicid| i94yr|i94mon|i94cit|i94res|i94port|arrdate|i94mode|i94addr|depdate|i94bir|i94visa|count|dtadfile|entdepa|entdepd|matflag|biryear|dtaddto|gender|airline|        admnum|fltno|visatype|
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+-------+-------+-------+-------+-------+------+-------+--------------+-----+--------+
# |5748903.0|2016.0|   4.0| 249.0| 111.0|    SFR|20574.0|    1.0|     CA|20625.0|  19.0|    3.0|  1.0|20160430|      G|      O|      M| 1997.0|    D/S|     F|     AF|9.499984463E10|00084|      F1|
# |5748931.0|2016.0|   4.0| 249.0| 249.0|    DET|20574.0|    1.0|     MI|20627.0|  23.0|    3.0|  1.0|20160430|      G|      O|      M| 1993.0|    D/S|     M|     DL|9.500494123E10|00019|      F1|
# |5748948.0|2016.0|   4.0| 249.0| 249.0|    BOS|20574.0|    1.0|     MA|   null|  26.0|    3.0|  1.0|20160430|      G|   null|   null| 1990.0|    D/S|     F|     LH|9.498655933E10|00422|      F1|
# |5749154.0|2016.0|   4.0| 251.0| 251.0|    NEW|20574.0|    1.0|     CT|20591.0|  33.0|    3.0|  1.0|20160430|      G|      O|      M| 1983.0|    D/S|     M|     UA|9.500290173E10|00085|      F1|
# |5749342.0|2016.0|   4.0| 251.0| 251.0|    NEW|20574.0|    1.0|     NJ|   null|  35.0|    3.0|  1.0|20160430|      G|   null|   null| 1981.0|    D/S|     M|     UA|9.492951603E10|00091|      F2|
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+-------+-------+-------+-------+-------+------+-------+--------------+-----+--------+
# only showing top 5 rows

# %%
# drop "dtaddto" equal to "D/S" 
# then can change "dtaddto" to date format since it contain "NaN"
immigrationPlus = immigrationNew.filter(immigrationNew.dtaddto != "D/S")

# %%
# top 5
immigrationPlus.show(5)
# Out:
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+-------+-------+-------+-------+--------+------+-------+--------------+-----+--------+
# |    cicid| i94yr|i94mon|i94cit|i94res|i94port|arrdate|i94mode|i94addr|depdate|i94bir|i94visa|count|dtadfile|entdepa|entdepd|matflag|biryear| dtaddto|gender|airline|        admnum|fltno|visatype|
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+-------+-------+-------+-------+--------+------+-------+--------------+-----+--------+
# |5748517.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     CA|20582.0|  40.0|    1.0|  1.0|20160430|      G|      O|      M| 1976.0|10292016|     F|     QF|9.495387003E10|00011|      B1|
# |5748518.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     NV|20591.0|  32.0|    1.0|  1.0|20160430|      G|      O|      M| 1984.0|10292016|     F|     VA|9.495562283E10|00007|      B1|
# |5748519.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20582.0|  29.0|    1.0|  1.0|20160430|      G|      O|      M| 1987.0|10292016|     M|     DL|9.495640653E10|00040|      B1|
# |5748520.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20588.0|  29.0|    1.0|  1.0|20160430|      G|      O|      M| 1987.0|10292016|     F|     DL|9.495645143E10|00040|      B1|
# |5748521.0|2016.0|   4.0| 245.0| 438.0|    LOS|20574.0|    1.0|     WA|20588.0|  28.0|    1.0|  1.0|20160430|      G|      O|      M| 1988.0|10292016|     M|     DL|9.495638813E10|00040|      B1|
# +---------+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+-------+-------+-------+-------+--------+------+-------+--------------+-----+--------+
# only showing top 5 rows

# %%
# schema
immigrationPlus.printSchema()
# Out:
# root
#  |-- cicid: double (nullable = true)
#  |-- i94yr: double (nullable = true)
#  |-- i94mon: double (nullable = true)
#  |-- i94cit: double (nullable = true)
#  |-- i94res: double (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: double (nullable = true)
#  |-- i94mode: double (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: double (nullable = true)
#  |-- i94bir: double (nullable = true)
#  |-- i94visa: double (nullable = true)
#  |-- count: double (nullable = true)
#  |-- dtadfile: string (nullable = true)
#  |-- entdepa: string (nullable = true)
#  |-- entdepd: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: double (nullable = true)
#  |-- dtaddto: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- admnum: double (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %% [markdown]
# Some data formats need to be changed.

# %%
# change to date
immigrationPlus = (immigrationPlus.withColumn("arrdate", expr("date_add('1960-01-01', arrdate)")).
                                    withColumn("depdate", expr("date_add('1960-01-01', depdate)")).
                                    withColumn("dtadfile", expr("to_date(dtadfile,'yyyyMMdd')")).
                                    withColumn("dtaddto", expr("to_date(dtaddto,'MMddyyyy')"))
                  )

# %%
# immigrationPlus.show(5)

# %%
# change to int
immigrationPlus = (immigrationPlus.withColumn("i94yr", col("i94yr").cast("float").cast("integer")).
                                     withColumn("i94mon", col("i94mon").cast("float").cast("integer")).
                                     withColumn("i94mode", col("i94mode").cast("float").cast("integer")).
                                     withColumn("i94bir", col("i94bir").cast("float").cast("integer")).
                                     withColumn("i94visa", col("i94visa").cast("float").cast("integer")).
                                     withColumn("count", col("count").cast("float").cast("integer")).
                                     withColumn("biryear", col("biryear").cast("float").cast("integer"))
                    )

# %%
# change to text
immigrationPlus = (immigrationPlus.withColumn("cicid", regexp_replace(col('cicid').cast("string"), '\.0', '')).
                    withColumn("i94cit", regexp_replace(col('i94cit').cast("string"), '\.0', '')).
                    withColumn("i94res", regexp_replace(col('i94res').cast("string"), '\.0', '')).
                    withColumn("admnum", col('admnum').cast("bigint").cast("string")))

# %%
# duplicates 
immigrationPlus.count() == immigrationPlus.drop_duplicates().count()
# Out:
# True

# %%
# data information
immigrationPlus.printSchema()
# Out:
# root
#  |-- cicid: string (nullable = true)
#  |-- i94yr: integer (nullable = true)
#  |-- i94mon: integer (nullable = true)
#  |-- i94cit: string (nullable = true)
#  |-- i94res: string (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: date (nullable = true)
#  |-- i94mode: integer (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: date (nullable = true)
#  |-- i94bir: integer (nullable = true)
#  |-- i94visa: integer (nullable = true)
#  |-- count: integer (nullable = true)
#  |-- dtadfile: date (nullable = true)
#  |-- entdepa: string (nullable = true)
#  |-- entdepd: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: integer (nullable = true)
#  |-- dtaddto: date (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- admnum: string (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
# top 5
immigrationPlus.show(5)
# Out:
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# |  cicid|i94yr|i94mon|i94cit|i94res|i94port|   arrdate|i94mode|i94addr|   depdate|i94bir|i94visa|count|  dtadfile|entdepa|entdepd|matflag|biryear|   dtaddto|gender|airline|     admnum|fltno|visatype|
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# |5748517| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     CA|2016-05-08|    40|      1|    1|2016-04-30|      G|      O|      M|   1976|2016-10-29|     F|     QF|94953870030|00011|      B1|
# |5748518| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     NV|2016-05-17|    32|      1|    1|2016-04-30|      G|      O|      M|   1984|2016-10-29|     F|     VA|94955622830|00007|      B1|
# |5748519| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-08|    29|      1|    1|2016-04-30|      G|      O|      M|   1987|2016-10-29|     M|     DL|94956406530|00040|      B1|
# |5748520| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-14|    29|      1|    1|2016-04-30|      G|      O|      M|   1987|2016-10-29|     F|     DL|94956451430|00040|      B1|
# |5748521| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-14|    28|      1|    1|2016-04-30|      G|      O|      M|   1988|2016-10-29|     M|     DL|94956388130|00040|      B1|
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# only showing top 5 rows

# %%
# immigrationPlus.select("i94yr").distinct().show() ## all the data are in 2016

# %%
# "i94addr" contain 458 distinct values
immigrationPlus.select("i94addr").distinct().count()
# Out:
# 458

# %%
# there are only 48 "state codes" in cities
len(sorted(citiesNewNoDup["State Code"].drop_duplicates()))
# Out:
# 48

# %%
# only select these records with "i94addr" in the cities
usStates = sorted(citiesNewNoDup["State Code"].drop_duplicates())

# %%
# filter the "i94addr" in cities "State Code" 
immigrationPlusNew = immigrationPlus.filter(immigrationPlus.i94addr.isin(usStates))

# %%
# "i94addr" distinct values
immigrationPlusNew.select("i94addr").distinct().count()
# Out:
# 48

# %%
# check
immigrationPlusNew.select("i94addr").distinct().show(50)
# Out:
# +-------+
# |i94addr|
# +-------+
# |     SC|
# |     AZ|
# |     LA|
# |     MN|
# |     NJ|
# |     DC|
# |     OR|
# |     VA|
# |     RI|
# |     KY|
# |     NH|
# |     MI|
# |     NV|
# |     WI|
# |     ID|
# |     CA|
# |     CT|
# |     NE|
# |     MT|
# |     NC|
# |     MD|
# |     DE|
# |     MO|
# |     IL|
# |     ME|
# |     WA|
# |     ND|
# |     MS|
# |     AL|
# |     IN|
# |     OH|
# |     TN|
# |     NM|
# |     IA|
# |     PA|
# |     SD|
# |     NY|
# |     TX|
# |     GA|
# |     MA|
# |     KS|
# |     FL|
# |     CO|
# |     AK|
# |     AR|
# |     OK|
# |     UT|
# |     HI|
# +-------+

# %%
# immigrationPlusNew.count()

# %%
## save the data to a parquet file in s3
(immigrationPlusNew.write
    .mode("overwrite")
    .parquet("s3a://udacity-capstone-project-bucket-test/immigration.parquet"))

# %% [markdown]
# ##### temperature
# 1. Only include 2003 onwards of temperature for data usage
# 2. Only include US

# %%
# year range
# print(min(temperature.dt), max(temperature.dt)) ## 1743-11-01, 2013-09-01

# %%
# temperature in 2003 and onwards and in US
temperatureUS10Yr = temperature[(temperature.Country == "United States") 
            & (temperature.dt >= "2003-01-01")].drop("Country", axis=1)

# %%
# Uncertainty
#print(min(temperatureUS10Yr.AverageTemperatureUncertainty), max(temperatureUS10Yr.AverageTemperatureUncertainty))
## 0.049 1.3219999999999998

# %%
# NaN rows
temperatureUS10Yr[temperatureUS10Yr.isnull().any(axis=1)]
# Out:
#                 dt AverageTemperature AverageTemperatureUncertainty   State
# 15106   2013-09-01                NaN                           NaN  Alaska
# 154725  2013-09-01                NaN                           NaN  Hawaii

# %%
# len(temperatureUS10Yr) ##6579

# %% [markdown]
# 2 out of 6579 contains NaN. Thus. drop.

# %%
# drop NaN
temperatureUS10YrNoNa = temperatureUS10Yr.dropna()

# %%
# change to date
temperatureUS10YrNoNa["dt"] = pd.to_datetime(temperatureUS10YrNoNa["dt"], format="%Y-%m-%d")
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# to float and round to 1
temperatureUS10YrNoNa[["AverageTemperature", "AverageTemperatureUncertainty"]] = temperatureUS10YrNoNa[["AverageTemperature", "AverageTemperatureUncertainty"]].astype(float).round(1)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
# duplicates
len(temperatureUS10YrNoNa) == len(temperatureUS10YrNoNa.drop_duplicates())
# Out:
# True

# %%
# data information
temperatureUS10YrNoNa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6577 entries, 10568 to 626439
# Data columns (total 4 columns):
# dt                               6577 non-null datetime64[ns]
# AverageTemperature               6577 non-null float64
# AverageTemperatureUncertainty    6577 non-null float64
# State                            6577 non-null object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 256.9+ KB

# %%
# top 5
temperatureUS10YrNoNa.head()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty    State
# 10568 2003-01-01                 4.8                            0.1  Alabama
# 10569 2003-02-01                 9.1                            0.2  Alabama
# 10570 2003-03-01                14.6                            0.2  Alabama
# 10571 2003-04-01                17.8                            0.2  Alabama
# 10572 2003-05-01                22.6                            0.2  Alabama

# %%
# save it as a csv and remove header and index and move it to aws s3 
temperatureUS10YrNoNa.to_csv("temperatureUS.csv", sep=",", header=False, index=False, encoding="utf-8")
s3 = boto3.resource('s3')
s3.meta.client.upload_file('temperatureUS.csv', 'udacity-capstone-project-bucket-test', 'temperatureUS.csv')

# %% [markdown]
# <a id="model"></a>

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
# * STAR Schema
# * dimension tables
#     * dim_airports ("State" PK; "num_airports")
#     * dim_temperature ("State", PK; "min_tm"; "max_tm")
#     * dim_population ("State", PK; age, gender, race population, household, etc)
# * fact tables
#     * fact_tourists ("cicid", PK; "State", FK)  <br>
#
# #### 3.2 Mapping Out Data Pipelines

# %% [markdown]
# <!-- ![title](airport_data_dictionary.png) -->

# %% [markdown]
# ##### Relationship between tables

# %% [markdown]
# "State Code" in "cities", "region" in "airports", and "i94addr" in "immigration" are all related to US state codes, which can be a key to join all the three tables. And "State" in "temperature" and "State" in "cities" are all related to US state names, which can be a key to join the two tables, then adding "State Code" to "temperature".
# Use "State Code" to link all the tables together to create relevant dimension and fact tables.

# %% [markdown]
# ##### State Codes

# %%
# airport region
np.array(sorted(airportUSNewNoNa.region.unique()))
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'U-A', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'],
#       dtype='<U3')

# %%
# city state
np.array(sorted(citiesNewNoDup["State Code"].unique()))
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VA', 'WA', 'WI'],
#       dtype='<U2')

# %%
# compare state codes in cities and airports
set(np.array(sorted(citiesNewNoDup["State Code"].unique()))).difference(set(np.array(sorted(airportUSNewNoNa.region.unique()))))
# Out:
# set()

# %%
# compare state codes in cities and airports
set(np.array(sorted(airportUSNewNoNa.region.unique()))).difference(set(np.array(sorted(citiesNewNoDup["State Code"].unique()))))
# Out:
# {'U-A', 'VT', 'WV', 'WY'}

# %% [markdown]
# 1. All the state codes in "cities" are in "airport".
# 2. {'U-A', 'VT', 'WV', 'WY'} are in "airport" but not in "cities".

# %%
# immigration i94addr
immigrationStates = immigrationPlusNew.select("i94addr").distinct().toPandas()

# %%
# top 5
immigrationStates.head()
# Out:
#   i94addr
# 0      SC
# 1      AZ
# 2      LA
# 3      MN
# 4      NJ

# %%
# compare state codes in cities and immigration
set(np.array(sorted(citiesNewNoDup["State Code"].unique()))).difference(set(np.array(sorted(immigrationStates["i94addr"].astype("str").unique()))))
# Out:
# set()

# %%
# compare state codes in cities and immigration
set(np.array(sorted(immigrationStates["i94addr"].astype("str").unique()))).difference(set(np.array(sorted(citiesNewNoDup["State Code"].unique()))))
# Out:
# set()

# %% [markdown]
# 1. All the state codes in the "cities" are in "immigration".

# %% [markdown]
# ##### State Names

# %%
# state names in "cities" 
np.array(sorted(citiesNewNoDup.State.unique()))
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Virginia', 'Washington', 'Wisconsin'],
#       dtype='<U20')

# %%
# state names in "temperature" 
np.array(sorted(temperatureUS10YrNoNa.State.unique()))
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District Of Columbia',
#        'Florida', 'Georgia (State)', 'Hawaii', 'Idaho', 'Illinois',
#        'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine',
#        'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype='<U20')

# %%
# compare state names in "cities" and "temperature"
set(np.array(sorted(citiesNewNoDup.State.unique()))).difference(set(np.array(sorted(temperatureUS10YrNoNa.State.unique()))))
# Out:
# {'District of Columbia', 'Georgia'}

# %%
# compare state names in "cities" and "temperature"
set(np.array(sorted(temperatureUS10YrNoNa.State.unique()))).difference(set(np.array(sorted(citiesNewNoDup.State.unique()))))
# Out:
# {'District Of Columbia',
#  'Georgia (State)',
#  'Vermont',
#  'West Virginia',
#  'Wyoming'}

# %% [markdown]
# 1. Change "District Of Columbia" to "District of Columbia" and "Georgia (State)" to "Georgia".
# 2. {'Vermont', 'West Virginia','Wyoming'} are in "temperature" not in "cities".

# %% [markdown]
# ##### Staging tables

# %% [markdown]
# **Redshift Data Warehouse**

# %% [markdown]
# ##### airport

# %%
# redshift connection
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
#print(conn_string)
# %sql $conn_string
# Out:
# 'Connected: udacity-data-pipelines@dev'

# %%
# %%sql
# DROP TABLE IF EXISTS airports;
# CREATE TABLE IF NOT EXISTS airports
#                (airport_id INT IDENTITY(0, 1) PRIMARY KEY,
#                ident VARCHAR NOT NULL,
#                type VARCHAR NOT NULL,
#                name VARCHAR NOT NULL,
#                elevation_ft FLOAT4 NOT NULL,
#                region VARCHAR NOT NULL,
#                longitude FLOAT8 NOT NULL,
#                latitude FLOAT8 NOT NULL);
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
query = """COPY airports (ident, type, name, elevation_ft, region, longitude, latitude)
FROM 's3://udacity-capstone-project-bucket-test/airportUS.csv'
credentials 'aws_access_key_id={};aws_secret_access_key={}' CSV;""".format(KEY, SECRET)
# %sql $query
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
# SELECT * FROM airports LIMIT 5;
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [(2, '00AK', 'small_airport', 'Lowell Field', 450.0, 'AK', -151.696, 59.9492),
#  (4, '00AL', 'small_airport', 'Epps Airpark', 820.0, 'AL', -86.7703, 34.8648),
#  (10, '00CA', 'small_airport', 'Goldstone /Gts/ Airport', 3038.0, 'CA', -116.888, 35.3505),
#  (16, '00FL', 'small_airport', 'River Oak Airport', 35.0, 'FL', -80.9692, 27.2309),
#  (18, '00GA', 'small_airport', 'Lt World Airport', 700.0, 'GA', -84.0683, 33.7675)]

# %% [markdown]
# ##### Cities

# %%
# %%sql
# DROP TABLE IF EXISTS cities;
# CREATE TABLE IF NOT EXISTS cities
#                (city_id INT IDENTITY(0, 1) PRIMARY KEY,
#                City VARCHAR NOT NULL,
#                State VARCHAR NOT NULL,
#                "Median Age" FLOAT4 NOT NULL,
#                "Male Population" INT NOT NULL,
#                "Female Population" INT NOT NULL,
#                "Total Population" INT NOT NULL,
#                "Number of Veterans" INT NOT NULL,
#                "Foreign-born" INT NOT NULL,
#                "Average Household Size" FLOAT4 NOT NULL,
#                "State Code" VARCHAR NOT NULL,
#                "American Indian and Alaska Native" FLOAT4,
#                "Asian" FLOAT4,
#                "Black or African-American" FLOAT4,
#                "Hispanic or Latino" FLOAT4 NOT NULL,
#                "White" FLOAT4 NOT NULL);
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
query = """COPY cities 
FROM 's3://udacity-capstone-project-bucket-test/citiesUS.csv'
credentials 'aws_access_key_id={};aws_secret_access_key={}'
CSV;""".format(KEY, SECRET)
# %sql $query
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
# SELECT * FROM stl_load_errors;

# %%
# %%sql
# SELECT * FROM cities LIMIT 5;
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [(1, 'Silver Spring', 'Maryland', 33.8, 40601, 41862, 82463, 1562, 30908, 2.6, 'MD', 1084.0, 8841.0, 21330.0, 25924.0, 37756.0),
#  (3, 'Quincy', 'Massachusetts', 41.0, 44129, 49500, 93629, 4147, 32935, 2.39, 'MA', 351.0, 30473.0, 3917.0, 2566.0, 58723.0),
#  (5, 'Hoover', 'Alabama', 38.5, 38040, 46799, 84839, 4819, 8229, 2.58, 'AL', None, 4759.0, 18191.0, 3430.0, 61869.0),
#  (7, 'Rancho Cucamonga', 'California', 34.5, 88127, 87105, 175232, 5821, 33878, 3.18, 'CA', 2789.0, 24519.0, 24437.0, 65823.0, 111832.0),
#  (9, 'Newark', 'New Jersey', 34.6, 138040, 143873, 281913, 5829, 86253, 2.73, 'NJ', 2268.0, 7349.0, 144961.0, 100432.0, 76402.0)]

# %% [markdown]
# ##### Immigration

# %%
immigrationPlusNew.show(5)
# Out:
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# |  cicid|i94yr|i94mon|i94cit|i94res|i94port|   arrdate|i94mode|i94addr|   depdate|i94bir|i94visa|count|  dtadfile|entdepa|entdepd|matflag|biryear|   dtaddto|gender|airline|     admnum|fltno|visatype|
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# |5748517| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     CA|2016-05-08|    40|      1|    1|2016-04-30|      G|      O|      M|   1976|2016-10-29|     F|     QF|94953870030|00011|      B1|
# |5748518| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     NV|2016-05-17|    32|      1|    1|2016-04-30|      G|      O|      M|   1984|2016-10-29|     F|     VA|94955622830|00007|      B1|
# |5748519| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-08|    29|      1|    1|2016-04-30|      G|      O|      M|   1987|2016-10-29|     M|     DL|94956406530|00040|      B1|
# |5748520| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-14|    29|      1|    1|2016-04-30|      G|      O|      M|   1987|2016-10-29|     F|     DL|94956451430|00040|      B1|
# |5748521| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-14|    28|      1|    1|2016-04-30|      G|      O|      M|   1988|2016-10-29|     M|     DL|94956388130|00040|      B1|
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# only showing top 5 rows

# %%
# %%sql
# DROP TABLE IF EXISTS immigration;
# CREATE TABLE IF NOT EXISTS immigration
#                (cicid VARCHAR PRIMARY KEY NOT NULL,
#                i94yr INT NOT NULL,
#                i94mon INT NOT NULL,
#                i94cit VARCHAR NOT NULL,
#                i94res VARCHAR NOT NULL,
#                i94port VARCHAR NOT NULL,
#                arrdate DATE NOT NULL,
#                i94mode INT NOT NULL,
#                i94addr VARCHAR,
#                depdate DATE,
#                i94bir INT,
#                i94visa INT NOT NULL,
#                count INT NOT NULL,
#                dtadfile DATE NOT NULL,
#                entdepa VARCHAR NOT NULL,
#                entdepd VARCHAR,
#                matflag VARCHAR,
#                biryear INT,
#                dtaddto DATE,
#                gender VARCHAR,
#                airline VARCHAR,
#                admnum VARCHAR NOT NULL,
#                fltno VARCHAR,
#                visatype VARCHAR NOT NULL);
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# # read the data 
# immigration=spark.read.parquet("s3a://udacity-capstone-project-bucket-test/immigration.parquet/*.parquet")

# %%
# # count
# immigration.count()
# Out:
# 2768864

# %%
# # top 5
# immigration.show(5)
# Out:
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# |  cicid|i94yr|i94mon|i94cit|i94res|i94port|   arrdate|i94mode|i94addr|   depdate|i94bir|i94visa|count|  dtadfile|entdepa|entdepd|matflag|biryear|   dtaddto|gender|airline|     admnum|fltno|visatype|
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# |5748517| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     CA|2016-05-08|    40|      1|    1|2016-04-30|      G|      O|      M|   1976|2016-10-29|     F|     QF|94953870030|00011|      B1|
# |5748518| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     NV|2016-05-17|    32|      1|    1|2016-04-30|      G|      O|      M|   1984|2016-10-29|     F|     VA|94955622830|00007|      B1|
# |5748519| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-08|    29|      1|    1|2016-04-30|      G|      O|      M|   1987|2016-10-29|     M|     DL|94956406530|00040|      B1|
# |5748520| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-14|    29|      1|    1|2016-04-30|      G|      O|      M|   1987|2016-10-29|     F|     DL|94956451430|00040|      B1|
# |5748521| 2016|     4|   245|   438|    LOS|2016-04-30|      1|     WA|2016-05-14|    28|      1|    1|2016-04-30|      G|      O|      M|   1988|2016-10-29|     M|     DL|94956388130|00040|      B1|
# +-------+-----+------+------+------+-------+----------+-------+-------+----------+------+-------+-----+----------+-------+-------+-------+-------+----------+------+-------+-----------+-----+--------+
# only showing top 5 rows

# %%
# data schema
immigration.printSchema()
# Out:
# root
#  |-- cicid: string (nullable = true)
#  |-- i94yr: integer (nullable = true)
#  |-- i94mon: integer (nullable = true)
#  |-- i94cit: string (nullable = true)
#  |-- i94res: string (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: date (nullable = true)
#  |-- i94mode: integer (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: date (nullable = true)
#  |-- i94bir: integer (nullable = true)
#  |-- i94visa: integer (nullable = true)
#  |-- count: integer (nullable = true)
#  |-- dtadfile: date (nullable = true)
#  |-- entdepa: string (nullable = true)
#  |-- entdepd: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: integer (nullable = true)
#  |-- dtaddto: date (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- admnum: string (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
query = """COPY immigration
FROM 's3://udacity-capstone-project-bucket-test/immigration.parquet/'
credentials 'aws_access_key_id={};aws_secret_access_key={}'
PARQUET;""".format(KEY, SECRET)
# %sql $query
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
# SELECT * FROM immigration LIMIT 5;
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [('5748518', 2016, 4, '245', '438', 'LOS', datetime.date(2016, 4, 30), 1, 'NV', datetime.date(2016, 5, 17), 32, 1, 1, datetime.date(2016, 4, 30), 'G', 'O', 'M', 1984, datetime.date(2016, 10, 29), 'F', 'VA', '94955622830', '00007', 'B1'),
#  ('5748519', 2016, 4, '245', '438', 'LOS', datetime.date(2016, 4, 30), 1, 'WA', datetime.date(2016, 5, 8), 29, 1, 1, datetime.date(2016, 4, 30), 'G', 'O', 'M', 1987, datetime.date(2016, 10, 29), 'M', 'DL', '94956406530', '00040', 'B1'),
#  ('5748520', 2016, 4, '245', '438', 'LOS', datetime.date(2016, 4, 30), 1, 'WA', datetime.date(2016, 5, 14), 29, 1, 1, datetime.date(2016, 4, 30), 'G', 'O', 'M', 1987, datetime.date(2016, 10, 29), 'F', 'DL', '94956451430', '00040', 'B1'),
#  ('5748521', 2016, 4, '245', '438', 'LOS', datetime.date(2016, 4, 30), 1, 'WA', datetime.date(2016, 5, 14), 28, 1, 1, datetime.date(2016, 4, 30), 'G', 'O', 'M', 1988, datetime.date(2016, 10, 29), 'M', 'DL', '94956388130', '00040', 'B1'),
#  ('5748522', 2016, 4, '245', '464', 'HHW', datetime.date(2016, 4, 30), 1, 'HI', datetime.date(2016, 5, 5), 57, 2, 1, datetime.date(2016, 4, 30), 'G', 'O', 'M', 1959, datetime.date(2016, 10, 29), 'M', 'NZ', '94981802830', '00010', 'B2')]

# %% [markdown]
# ##### Temperature

# %%
# %%sql
# DROP TABLE IF EXISTS temperature;
# CREATE TABLE IF NOT EXISTS temperature
#                (temp_id INT IDENTITY(0, 1) PRIMARY KEY,
#                dt DATE NOT NULL,
#                AverageTemperature FLOAT4 NOT NULL,
#                AverageTemperatureUncertainty FLOAT4 NOT NULL,
#                State VARCHAR NOT NULL
#                );
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
query = """COPY temperature 
FROM 's3://udacity-capstone-project-bucket-test/temperatureUS.csv'
credentials 'aws_access_key_id={};aws_secret_access_key={}'
CSV;""".format(KEY, SECRET)
# %sql $query
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
# SELECT * FROM stl_load_errors;

# %%
# %%sql
# SELECT * FROM temperature LIMIT 5;
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [(0, datetime.date(2003, 1, 1), 4.8, 0.1, 'Alabama'),
#  (2, datetime.date(2003, 2, 1), 9.1, 0.2, 'Alabama'),
#  (4, datetime.date(2003, 3, 1), 14.6, 0.2, 'Alabama'),
#  (6, datetime.date(2003, 4, 1), 17.8, 0.2, 'Alabama'),
#  (8, datetime.date(2003, 5, 1), 22.6, 0.2, 'Alabama')]

# %% [markdown]
# ##### Normalization

# %% [markdown]
# dim_airports

# %%
# %%sql
# DROP TABLE IF EXISTS dim_airports;
# CREATE TABLE dim_airports AS
#     SELECT DISTINCT tb.region,  totalAirport FROM
#         (SELECT region, COUNT(ident) AS totalAirport
#         FROM airports
#         GROUP BY 1) tb
#         WHERE region IN (SELECT DISTINCT "State Code" FROM cities)
#         AND region IN (SELECT DISTINCT i94addr FROM immigration);
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM dim_airports LIMIT 5
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [('FL', 523), ('MO', 411), ('NY', 400), ('OR', 357), ('SD', 162)]

# %% [markdown]
# dim_cities

# %%
# %%sql
# DROP TABLE IF EXISTS dim_cities;
# CREATE TABLE dim_cities AS
#     SELECT DISTINCT tb.* FROM
#         (SELECT "State Code",
#         ROUND(AVG("Median Age"), 1) AS "Median Age",
#         SUM("Male Population") AS "Male Population",
#         SUM("Female Population") AS "Female Population",
#         SUM("Total Population") AS "Total Population",
#         SUM("Number of Veterans") AS "Number of Veterans",
#         SUM("Foreign-born") AS "Foreign-born",
#         ROUND(AVG("Average Household Size"), 1) AS "Average Household Size",
#         ROUND(SUM("American Indian and Alaska Native"), 1) AS "American Indian and Alaska Native",
#         ROUND(SUM([Asian]), 1) AS [Asian],
#         ROUND(SUM("Black or African-American"), 1) AS "Black or African-American",
#         ROUND(SUM("Hispanic or Latino"), 1) AS "Hispanic or Latino",
#         ROUND(SUM([White]), 1) AS [White] FROM cities
#         GROUP BY "State Code") tb
#         WHERE "State Code" IN (SELECT DISTINCT region FROM airports)
#         AND "State Code" IN (SELECT DISTINCT i94addr FROM immigration);
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM dim_cities LIMIT 5
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [('FL', 39.0, 3236773, 3487375, 6724148, 372997, 1684897, 2.8, 43541.0, 241587.5, 1517568.5, 1906897.5, 4439764.5),
#  ('SC', 34.2, 260944, 272713, 533657, 33463, 27744, 2.5, 3492.0, 19852.3, 152653.3, 29162.7, 346412.7),
#  ('WA', 35.3, 1245605, 1254502, 2500107, 153126, 440962, 2.6, 60248.0, 346995.0, 187584.0, 324070.0, 1913484.0),
#  ('ID', 34.8, 199103, 199780, 398883, 26380, 28126, 2.7, 6705.0, 13985.0, 7822.0, 48142.0, 370314.0),
#  ('MT', 35.5, 87707, 93587, 181294, 13854, 5977, 2.3, 9684.0, 4165.0, 3349.0, 10000.0, 169026.0)]

# %% [markdown]
# dim_temperature

# %% [markdown]
# There is no funcion like PIVOT in Sqlite. Thus. use the following SQL query to achieve the function.

# %%
# %%sql
# DROP TABLE IF EXISTS dim_temperature;
# CREATE TABLE dim_temperature AS
#     WITH season AS (
#     SELECT
#         CASE
#         WHEN EXTRACT(MONTH FROM dt) IN (03, 04, 05) THEN 'Spring'
#         WHEN EXTRACT(MONTH FROM dt) IN (06, 07, 08) THEN 'Summer'
#         WHEN EXTRACT(MONTH FROM dt) IN (09, 10, 11) THEN 'Fall'
#         WHEN EXTRACT(MONTH FROM dt) IN (12, 01, 02) THEN 'Winter'
#         END Season,
#         CASE
#         WHEN State = 'Georgia (State)' THEN 'Georgia'
#         WHEN State = 'District Of Columbia' THEN 'District of Columbia'
#         ELSE State
#         END AS State
#         ,
#         ROUND(AVG(AverageTemperature), 1) AS AverageTemperature
#         FROM temperature
#         GROUP BY 1, 2
#     )
#     SELECT DISTINCT cities."State Code", FallAvgTemp, SummerAvgTemp, SpringAvgTemp, WinterAvgTemp FROM
#         (SELECT State,
#         CASE WHEN Season = 'Fall' THEN AverageTemperature END AS FallAvgTemp FROM season) fall
#         JOIN (
#         SELECT State,
#         CASE WHEN Season = 'Summer' THEN AverageTemperature END AS SummerAvgTemp FROM season
#         ) summer
#         ON fall.State = Summer.State
#         JOIN (
#         SELECT State,
#         CASE WHEN Season = 'Spring' THEN AverageTemperature END AS SpringAvgTemp FROM season
#         ) spring
#         ON fall.State = spring.State
#         JOIN (
#         SELECT State,
#         CASE WHEN Season = 'Winter' THEN AverageTemperature END AS WinterAvgTemp FROM season
#         ) winter
#         ON fall.State = winter.State
#         JOIN cities
#         ON fall.State = cities.State
#         WHERE cities."State Code" IN (SELECT DISTINCT region FROM airports)
#         AND cities."State Code" IN (SELECT DISTINCT i94addr FROM immigration)
#         AND FallAvgTemp IS NOT NULL AND SummerAvgTemp IS NOT NULL AND SpringAvgTemp IS NOT NULL AND WinterAvgTemp IS NOT NULL
# ;
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM dim_temperature LIMIT 5
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [('PA', 11.8, 21.5, 9.7, -1.7),
#  ('AR', 17.3, 26.8, 16.6, 5.6),
#  ('RI', 12.6, 21.1, 8.6, -0.7),
#  ('DC', 14.2, 24.2, 12.4, 1.4),
#  ('LA', 20.8, 28.1, 20.0, 10.9)]

# %% [markdown]
# fact_immigration

# %%
# %%sql
# DROP TABLE IF EXISTS fact_immigration;
# CREATE TABLE fact_immigration AS
#                 SELECT * FROM
#                 immigration
#                 WHERE i94addr IN
#                 (SELECT DISTINCT "State Code" FROM cities)
#                 AND i94addr IN (SELECT DISTINCT region FROM airports);
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM fact_immigration LIMIT 5
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [('5901585', 2016, 4, '111', '111', 'CHM', datetime.date(2016, 4, 1), 1, 'NY', None, 21, 2, 1, datetime.date(2016, 5, 2), 'A', None, None, 1995, datetime.date(2016, 6, 30), 'F', 'AC', '42339986533', None, 'WT'),
#  ('5901589', 2016, 4, '111', '111', 'CHM', datetime.date(2016, 4, 1), 9, 'NJ', None, 37, 2, 1, datetime.date(2016, 5, 2), 'A', None, None, 1979, datetime.date(2016, 6, 29), 'M', None, '42309454033', None, 'WT'),
#  ('5902170', 2016, 4, '112', '112', 'BLA', datetime.date(2016, 4, 1), 9, 'OR', None, None, 2, 1, datetime.date(2016, 5, 2), 'A', None, None, None, datetime.date(2016, 6, 29), 'M', None, '86558290728', None, 'WT'),
#  ('5909168', 2016, 4, '373', '373', 'WPB', datetime.date(2016, 4, 1), 9, 'FL', datetime.date(2016, 4, 4), 33, 1, 1, datetime.date(2016, 5, 5), 'A', 'D', 'M', 1983, datetime.date(2016, 9, 30), 'X', None, '49468112027', None, 'B1'),
#  ('5910502', 2016, 4, '464', '438', 'PEV', datetime.date(2016, 4, 1), 1, 'FL', None, 33, 1, 1, datetime.date(2016, 5, 6), 'A', 'W', 'M', 1983, datetime.date(2016, 10, 1), 'M', 'MM', '12797272727', '04242', 'B1')]

# %% [markdown]
# <a id='check'></a>

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %% [markdown]
# ##### Check the relationship among the normalized tables

# %%
# %%sql
# SELECT DISTINCT i94addr, dc."State Code", da.region, dt."State Code" FROM fact_immigration f
# LEFT JOIN dim_cities dc
# ON f.i94addr = dc."State Code"
# LEFT JOIN dim_airports da
# ON f.i94addr = da.region
# LEFT JOIN dim_temperature dt
# ON f.i94addr = dt."State Code"
# ORDER BY 1
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 48 rows affected.
# [('AK', 'AK', 'AK', 'AK'),
#  ('AL', 'AL', 'AL', 'AL'),
#  ('AR', 'AR', 'AR', 'AR'),
#  ('AZ', 'AZ', 'AZ', 'AZ'),
#  ('CA', 'CA', 'CA', 'CA'),
#  ('CO', 'CO', 'CO', 'CO'),
#  ('CT', 'CT', 'CT', 'CT'),
#  ('DC', 'DC', 'DC', 'DC'),
#  ('DE', 'DE', 'DE', 'DE'),
#  ('FL', 'FL', 'FL', 'FL'),
#  ('GA', 'GA', 'GA', 'GA'),
#  ('HI', 'HI', 'HI', 'HI'),
#  ('IA', 'IA', 'IA', 'IA'),
#  ('ID', 'ID', 'ID', 'ID'),
#  ('IL', 'IL', 'IL', 'IL'),
#  ('IN', 'IN', 'IN', 'IN'),
#  ('KS', 'KS', 'KS', 'KS'),
#  ('KY', 'KY', 'KY', 'KY'),
#  ('LA', 'LA', 'LA', 'LA'),
#  ('MA', 'MA', 'MA', 'MA'),
#  ('MD', 'MD', 'MD', 'MD'),
#  ('ME', 'ME', 'ME', 'ME'),
#  ('MI', 'MI', 'MI', 'MI'),
#  ('MN', 'MN', 'MN', 'MN'),
#  ('MO', 'MO', 'MO', 'MO'),
#  ('MS', 'MS', 'MS', 'MS'),
#  ('MT', 'MT', 'MT', 'MT'),
#  ('NC', 'NC', 'NC', 'NC'),
#  ('ND', 'ND', 'ND', 'ND'),
#  ('NE', 'NE', 'NE', 'NE'),
#  ('NH', 'NH', 'NH', 'NH'),
#  ('NJ', 'NJ', 'NJ', 'NJ'),
#  ('NM', 'NM', 'NM', 'NM'),
#  ('NV', 'NV', 'NV', 'NV'),
#  ('NY', 'NY', 'NY', 'NY'),
#  ('OH', 'OH', 'OH', 'OH'),
#  ('OK', 'OK', 'OK', 'OK'),
#  ('OR', 'OR', 'OR', 'OR'),
#  ('PA', 'PA', 'PA', 'PA'),
#  ('RI', 'RI', 'RI', 'RI'),
#  ('SC', 'SC', 'SC', 'SC'),
#  ('SD', 'SD', 'SD', 'SD'),
#  ('TN', 'TN', 'TN', 'TN'),
#  ('TX', 'TX', 'TX', 'TX'),
#  ('UT', 'UT', 'UT', 'UT'),
#  ('VA', 'VA', 'VA', 'VA'),
#  ('WA', 'WA', 'WA', 'WA'),
#  ('WI', 'WI', 'WI', 'WI')]

# %%
# %%sql
# SELECT COUNT(*), MIN("State Code"), MAX("State Code") FROM dim_cities
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(48, 'AK', 'WI')]

# %%
# %%sql
# SELECT COUNT(*), MIN("State Code"), MAX("State Code") FROM dim_temperature
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(48, 'AK', 'WI')]

# %%
# %%sql
# SELECT COUNT(DISTINCT region), MIN(region), MAX(region) FROM dim_airports
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(48, 'AK', 'WI')]

# %%
# %%sql
# SELECT COUNT(DISTINCT i94addr), MIN(i94addr), MAX(i94addr) FROM fact_immigration
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(48, 'AK', 'WI')]

# %% [markdown]
# All the state codes in the dimension tables and fact table can be matched.

# %% [markdown]
# ##### Check the normalized tables with the original tables

# %% [markdown]
# **cities**

# %%
# %%sql
# SELECT * FROM dim_cities
# WHERE "State Code" = 'AL'
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [('AL', 36.2, 497248, 552381, 1049629, 71543, 52154, 2.4, 8084.0, 28769.0, 521068.0, 39313.0, 498920.0)]

# %%
# original cities
cities[cities["State Code"] == "AL"]
# Out:
#             City    State Median Age Male Population Female Population  \
# 2         Hoover  Alabama       38.5           38040             46799
# 67    Montgomery  Alabama       35.4           94582            106004
# 68    Huntsville  Alabama       38.1           91764             97350
# 101   Huntsville  Alabama       38.1           91764             97350
# 212   Birmingham  Alabama       35.6          102122            112789
# 375   Huntsville  Alabama       38.1           91764             97350
# 479       Dothan  Alabama       38.9           32172             35364
# 500       Dothan  Alabama       38.9           32172             35364
# 552   Montgomery  Alabama       35.4           94582            106004
# 598   Tuscaloosa  Alabama       29.1           47293             51045
# 805   Tuscaloosa  Alabama       29.1           47293             51045
# 893   Montgomery  Alabama       35.4           94582            106004
# 960       Hoover  Alabama       38.5           38040             46799
# 1063  Birmingham  Alabama       35.6          102122            112789
# 1064      Dothan  Alabama       38.9           32172             35364
# 1245  Huntsville  Alabama       38.1           91764             97350
# 1291  Montgomery  Alabama       35.4           94582            106004
# 1410      Hoover  Alabama       38.5           38040             46799
# 1416  Tuscaloosa  Alabama       29.1           47293             51045
# 1497  Huntsville  Alabama       38.1           91764             97350
# 1541      Hoover  Alabama       38.5           38040             46799
# 1580      Dothan  Alabama       38.9           32172             35364
# 1777  Tuscaloosa  Alabama       29.1           47293             51045
# 1925      Dothan  Alabama       38.9           32172             35364
# 2025  Birmingham  Alabama       35.6          102122            112789
# 2063      Mobile  Alabama       38.0           91275            103030
# 2064      Mobile  Alabama       38.0           91275            103030
# 2220  Montgomery  Alabama       35.4           94582            106004
# 2231  Birmingham  Alabama       35.6          102122            112789
# 2320      Mobile  Alabama       38.0           91275            103030
# 2370  Tuscaloosa  Alabama       29.1           47293             51045
# 2507      Mobile  Alabama       38.0           91275            103030
# 2508      Mobile  Alabama       38.0           91275            103030
# 2627  Birmingham  Alabama       35.6          102122            112789
#
#      Total Population Number of Veterans Foreign-born Average Household Size  \
# 2               84839               4819         8229                   2.58
# 67             200586              14955         9337                   2.41
# 68             189114              16637        12691                   2.18
# 101            189114              16637        12691                   2.18
# 212            214911              13212         8258                   2.21
# 375            189114              16637        12691                   2.18
# 479             67536               6334         1699                   2.59
# 500             67536               6334         1699                   2.59
# 552            200586              14955         9337                   2.41
# 598             98338               3647         4706                   2.67
# 805             98338               3647         4706                   2.67
# 893            200586              14955         9337                   2.41
# 960             84839               4819         8229                   2.58
# 1063           214911              13212         8258                   2.21
# 1064            67536               6334         1699                   2.59
# 1245           189114              16637        12691                   2.18
# 1291           200586              14955         9337                   2.41
# 1410            84839               4819         8229                   2.58
# 1416            98338               3647         4706                   2.67
# 1497           189114              16637        12691                   2.18
# 1541            84839               4819         8229                   2.58
# 1580            67536               6334         1699                   2.59
# 1777            98338               3647         4706                   2.67
# 1925            67536               6334         1699                   2.59
# 2025           214911              13212         8258                   2.21
# 2063           194305              11939         7234                    2.4
# 2064           194305              11939         7234                    2.4
# 2220           200586              14955         9337                   2.41
# 2231           214911              13212         8258                   2.21
# 2320           194305              11939         7234                    2.4
# 2370            98338               3647         4706                   2.67
# 2507           194305              11939         7234                    2.4
# 2508           194305              11939         7234                    2.4
# 2627           214911              13212         8258                   2.21
#
#      State Code                               Race   Count
# 2            AL                              Asian    4759
# 67           AL                              White   73545
# 68           AL  American Indian and Alaska Native    1755
# 101          AL                 Hispanic or Latino   10887
# 212          AL                              Asian    1500
# 375          AL          Black or African-American   61561
# 479          AL                              Asian    1175
# 500          AL                 Hispanic or Latino    1704
# 552          AL  American Indian and Alaska Native    1277
# 598          AL                              Asian    2733
# 805          AL                 Hispanic or Latino    2475
# 893          AL                 Hispanic or Latino    6648
# 960          AL          Black or African-American   18191
# 1063         AL  American Indian and Alaska Native    1319
# 1064         AL          Black or African-American   23243
# 1245         AL                              Asian    6566
# 1291         AL          Black or African-American  121360
# 1410         AL                 Hispanic or Latino    3430
# 1416         AL  American Indian and Alaska Native     261
# 1497         AL                              White  121904
# 1541         AL                              White   61869
# 1580         AL                              White   43516
# 1777         AL          Black or African-American   42331
# 1925         AL  American Indian and Alaska Native     656
# 2025         AL                              White   51728
# 2063         AL                              Asian    5518
# 2064         AL  American Indian and Alaska Native    2816
# 2220         AL                              Asian    6518
# 2231         AL          Black or African-American  157985
# 2320         AL                              White   93755
# 2370         AL                              White   52603
# 2507         AL                 Hispanic or Latino    5229
# 2508         AL          Black or African-American   96397
# 2627         AL                 Hispanic or Latino    8940

# %% [markdown]
# The information listed in the "dim_cities" is the same as the information listed in the original "cities".

# %% [markdown]
# **airports**

# %%
# %%sql
# SELECT * FROM dim_airports
# WHERE region = 'AL'
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [('AL', 197)]

# %%
# original airport
(airport[(airport.iso_region == 'US-AL') &
        ~(airport.type == "closed") & 
        airport.type.str.contains("airport") & 
        ~airport.elevation_ft.isna()].
        drop(["continent","iata_code", "gps_code", "local_code", "municipality"], axis=1).drop_duplicates())
# Out:
#          ident            type  \
# 3         00AL   small_airport
# 65        01AL   small_airport
# 129       02AL   small_airport
# 605       0AL1   small_airport
# 609       0AL5   small_airport
# 613       0AL9   small_airport
# 791        0J0   small_airport
# 1500       15A   small_airport
# 1786      1AL2   small_airport
# 1788      1AL4   small_airport
# 1789      1AL5   small_airport
# 1792      1AL8   small_airport
# 2029       1M3   small_airport
# 2558       23A   small_airport
# 2686       25A   small_airport
# 2747      26AL   small_airport
# 2801      27AL   small_airport
# 2967       2A8   small_airport
# 2980      2AL1   small_airport
# 2982      2AL3   small_airport
# 2984      2AL5   small_airport
# 2985      2AL6   small_airport
# 2986      2AL7   small_airport
# 2987      2AL8   small_airport
# 3944      36AL   small_airport
# 4143       3A0   small_airport
# 4158      3AL1   small_airport
# 4162      3AL5   small_airport
# 4163      3AL6   small_airport
# 4164      3AL7   small_airport
# ...        ...             ...
# 27680     KJFX   small_airport
# 27684     KJKA   small_airport
# 27929     KM22   small_airport
# 27954     KM55   small_airport
# 27976     KM95   small_airport
# 28009     KMDQ   small_airport
# 28032     KMGM   large_airport
# 28098     KMOB   large_airport
# 28128     KMSL  medium_airport
# 28150     KMVC   small_airport
# 28165     KMXF  medium_airport
# 28212     KNBJ   small_airport
# 28219     KNFD   small_airport
# 28253     KNQB   small_airport
# 28430     KOZR  medium_airport
# 28596     KPLR   small_airport
# 28631     KPRN   small_airport
# 28680     KPYP   small_airport
# 29917     KSCD   small_airport
# 29931     KSEM   small_airport
# 30106     KTCL  medium_airport
# 30149     KTOI  medium_airport
# 30541      L44   small_airport
# 32622      M38   small_airport
# 40714      S63   small_airport
# 49078  US-0064   small_airport
# 49623  US-0608   small_airport
# 49697  US-0682   small_airport
# 49700  US-0685   small_airport
# 49701  US-0686   small_airport
#
#                                                     name elevation_ft  \
# 3                                           Epps Airpark          820
# 65                                   Ware Island Airport          344
# 129                                           Bass Field           61
# 605                                       Resort Airport           97
# 609                                     Flomaton Airport          247
# 613                                 Wilson Creek Airport          590
# 791                          Abbeville Municipal Airport          468
# 1500           Mark Reynolds/North Mobile County Airport           60
# 1786                                 Tri-L Acres Airport          580
# 1788                                     Elsanor Airport          180
# 1789                                         Berry Field          170
# 1792                                         Moore Field          730
# 2029                                     Ardmore Airport          920
# 2558                                     Mallard Airport          185
# 2686                                      Mcminn Airport          680
# 2747                                    Richardson Field          180
# 2801                                Little Texas Airport          500
# 2967                           Addison Municipal Airport          786
# 2980                                     Collier Airpark           74
# 2982                            Emerald Mountain Airport          365
# 2984                              Flying J Ranch Airport         1430
# 2985                             Dale O. Galer Aerodrome           40
# 2986                        Mount Aero Lake Farm Airport          625
# 2987                                Finkley Farm Airport          413
# 3944                              Hidden Springs Airpark          346
# 4143                        Grove Hill Municipal Airport          478
# 4158                              Flying H Ranch Airport          264
# 4162                                Edwards Farm Airport          750
# 4163                              Town & Country Airpark          730
# 4164                                       Flowers Field          280
# ...                                                  ...          ...
# 27680                 Walker County Airport-Bevill Field          482
# 27684                               Jack Edwards Airport           17
# 27929                                    Bill Pugh Field          723
# 27954                               Lamar County Airport          463
# 27976                               Richard Arthur Field          357
# 28009  Madison County Executive Airport-Tom Sharp Jr ...          756
# 28032       Montgomery Regional (Dannelly Field) Airport          221
# 28098                            Mobile Regional Airport          219
# 28128                 Northwest Alabama Regional Airport          551
# 28150                     Monroe County Aeroplex Airport          419
# 28165                             Maxwell Air Force Base          171
# 28212                         Naval Outlying Field Barin           54
# 28219                            Summerdale Nolf Airport          149
# 28253                            Silverhill Nolf Airport          129
# 28430                 Cairns AAF (Fort Rucker) Air Field          301
# 28596                            St Clair County Airport          485
# 28631                      Mac Crenshaw Memorial Airport          451
# 28680   Centre-Piedmont-Cherokee County Regional Airport          596
# 29917           Merkel Field Sylacauga Municipal Airport          569
# 29931                                        Craig Field          166
# 30106                        Tuscaloosa Regional Airport          170
# 30149  Troy Municipal Airport at N Kenneth Campbell F...          398
# 30541                                 Moundville Airport          162
# 32622                                Hazel Green Airport          814
# 40714                                  Skyharbor Airport          125
# 49078                             Hickory Grove STOLport          700
# 49623                          Hazel Green Acres Airport          908
# 49697                                    J5 Mike Airport          680
# 49700                              Rocky Springs Airpark          649
# 49701                                      Treeo Airport          130
#
#       iso_country iso_region                             coordinates
# 3              US      US-AL   -86.77030181884766, 34.86479949951172
# 65             US      US-AL   -86.51390075683594, 32.94599914550781
# 129            US      US-AL   -87.76439666748047, 30.37150001525879
# 605            US      US-AL  -87.65689849853516, 30.443899154663086
# 609            US      US-AL   -87.25279998779297, 31.03219985961914
# 613            US      US-AL  -87.63249969482422, 34.849998474121094
# 791            US      US-AL  -85.23880004882812, 31.600200653076172
# 1500           US      US-AL   -87.98059844970703, 30.91320037841797
# 1786           US      US-AL  -86.59750366210938, 33.248600006103516
# 1788           US      US-AL  -87.55940246582031, 30.544700622558594
# 1789           US      US-AL     -87.747802734375, 30.63640022277832
# 1792           US      US-AL   -86.47440338134766, 33.61109924316406
# 2029           US      US-AL  -86.88469696044922, 34.977901458740234
# 2558           US      US-AL   -88.26809692382812, 32.49509811401367
# 2686           US      US-AL   -85.82550048828125, 33.73979949951172
# 2747           US      US-AL   -88.27860260009766, 30.62420082092285
# 2801           US      US-AL   -85.55819702148438, 32.45349884033203
# 2967           US      US-AL                   -87.158353, 34.217038
# 2980           US      US-AL  -87.77780151367188, 30.424100875854492
# 2982           US      US-AL   -86.11920166015625, 32.45539855957031
# 2984           US      US-AL  -85.66500091552734, 34.392799377441406
# 2985           US      US-AL                   -88.197307, 30.491981
# 2986           US      US-AL  -86.72309875488281, 34.062801361083984
# 2987           US      US-AL   -85.24810028076172, 32.42110061645508
# 3944           US      US-AL                   -85.534407, 31.491973
# 4143           US      US-AL  -87.76139831542969, 31.689300537109375
# 4158           US      US-AL    -85.685302734375, 31.050399780273438
# 4162           US      US-AL   -85.76390075683594, 33.83530044555664
# 4163           US      US-AL     -86.4124984741211, 33.4901008605957
# 4164           US      US-AL    -87.5199966430664, 32.28499984741211
# ...           ...        ...                                     ...
# 27680          US      US-AL               -87.31420135, 33.90200043
# 27684          US      US-AL               -87.67179871, 30.29050064
# 27929          US      US-AL                   -87.711304, 34.445301
# 27954          US      US-AL    -88.1155014038086, 33.84669876098633
# 27976          US      US-AL                     -87.815002, 33.7122
# 28009          US      US-AL                -86.55750275, 34.8614006
# 28032          US      US-AL               -86.39399719, 32.30059814
# 28098          US      US-AL       -88.242797851562, 30.691200256348
# 28128          US      US-AL               -87.61019897, 34.74530029
# 28150          US      US-AL                      -87.350996, 31.458
# 28165          US      US-AL                     -86.365799, 32.3829
# 28212          US      US-AL  -87.63529968259999, 30.389099121100003
# 28219          US      US-AL  -87.64550018310547, 30.507699966430664
# 28253          US      US-AL  -87.80970001220703, 30.563600540161133
# 28430          US      US-AL               -85.71340179, 31.27569962
# 28596          US      US-AL       -86.249099731445, 33.558799743652
# 28631          US      US-AL               -86.61070251, 31.84569931
# 28680          US      US-AL                   -85.610069, 34.089977
# 29917          US      US-AL   -86.30549621582031, 33.17179870605469
# 29931          US      US-AL       -86.987800598145, 32.343898773193
# 30106          US      US-AL       -87.611396789551, 33.220600128174
# 30149          US      US-AL                   -86.012101, 31.860399
# 30541          US      US-AL    -87.6406021118164, 32.96820068359375
# 32622          US      US-AL   -86.64689636230469, 34.91619873046875
# 40714          US      US-AL  -87.10420227050781, 32.366798400878906
# 49078          US      US-AL       -85.702796936, 33.901699066199996
# 49623          US      US-AL                   -86.692304, 34.980471
# 49697          US      US-AL                   -86.222286, 34.666347
# 49700          US      US-AL                   -87.077074, 33.988596
# 49701          US      US-AL                   -87.822583, 30.591805
#
# [197 rows x 7 columns]

# %% [markdown]
# Number of airports in the "dim_airports" can be matched to the number in the original "airport" table.

# %% [markdown]
# **temperature**

# %%
# %%sql
# SELECT * FROM dim_temperature
# WHERE "State Code" = 'AL'
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [('AL', 18.6, 26.9, 17.9, 8.4)]

# %%
# original temperature table
spring = round(temperature[(temperature.dt.str.contains("-03-|-04-|-05-")) & (temperature.State == "Alabama")]["AverageTemperature"].astype(float).mean(), 1)
summer = round(temperature[(temperature.dt.str.contains("-06-|-07-|-08-")) & (temperature.State == "Alabama")]["AverageTemperature"].astype(float).mean(), 1)
autumn = round(temperature[(temperature.dt.str.contains("-09-|-10-|-11-")) & (temperature.State == "Alabama")]["AverageTemperature"].astype(float).mean(), 1)
winter = round(temperature[(temperature.dt.str.contains("-12-|-01-|-02-")) & (temperature.State == "Alabama")]["AverageTemperature"].astype(float).mean(), 1)
print("Fall:{}\tSummer:{}\tSpring:{}\tWinter:{}".format(autumn, summer, spring, winter))
# Out:
# Fall:17.4	Summer:26.0	Spring:17.0	Winter:8.0

# %% [markdown]
# The temperature in "dim_temperature" is a little higher than original "temperature" table.

# %% [markdown]
# **immigration**

# %%
# %%sql
# SELECT * FROM fact_immigration LIMIT 5;
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 5 rows affected.
# [('5901585', 2016, 4, '111', '111', 'CHM', datetime.date(2016, 4, 1), 1, 'NY', None, 21, 2, 1, datetime.date(2016, 5, 2), 'A', None, None, 1995, datetime.date(2016, 6, 30), 'F', 'AC', '42339986533', None, 'WT'),
#  ('5901589', 2016, 4, '111', '111', 'CHM', datetime.date(2016, 4, 1), 9, 'NJ', None, 37, 2, 1, datetime.date(2016, 5, 2), 'A', None, None, 1979, datetime.date(2016, 6, 29), 'M', None, '42309454033', None, 'WT'),
#  ('5902170', 2016, 4, '112', '112', 'BLA', datetime.date(2016, 4, 1), 9, 'OR', None, None, 2, 1, datetime.date(2016, 5, 2), 'A', None, None, None, datetime.date(2016, 6, 29), 'M', None, '86558290728', None, 'WT'),
#  ('5909168', 2016, 4, '373', '373', 'WPB', datetime.date(2016, 4, 1), 9, 'FL', datetime.date(2016, 4, 4), 33, 1, 1, datetime.date(2016, 5, 5), 'A', 'D', 'M', 1983, datetime.date(2016, 9, 30), 'X', None, '49468112027', None, 'B1'),
#  ('5910502', 2016, 4, '464', '438', 'PEV', datetime.date(2016, 4, 1), 1, 'FL', None, 33, 1, 1, datetime.date(2016, 5, 6), 'A', 'W', 'M', 1983, datetime.date(2016, 10, 1), 'M', 'MM', '12797272727', '04242', 'B1')]

# %%
# %%sql
# SELECT COUNT(*) FROM fact_immigration
# WHERE i94addr = 'AL'
# Out:
#  * postgresql://udacity-data-pipelines:***@redshift-cluster-1.cxdkjytbphwr.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(8036,)]

# %%
# original immigration
immigration[immigration.i94addr == "AL"].count()
# Out:
# 8188

# %% [markdown]
# The information listed in the "fact_immigration" is the very close to the information in the original "immigration" table.

# %% [markdown]
# In conclusion, the information in the original tables is pretty close to the information in the normalized tables.

# %% [markdown]
# #### 4.3 Data dictionary
# Create a data dictionary for your data model. For each field, provide a brief description of what the data is and where it came from. You can include the data dictionary in the notebook or in a separate file.

# %%
# %%sql
# SELECT * FROM dim_cities LIMIT 5

# %% [markdown]
# * **dim_cities**:
#     * "State Code" (PK): Code for states.
#     * "Median Age": Median Age for population for US 2015 Census.
#     * "Male Population": Male population for US 2015 Census.
#     * "Female Population": Female Population for US 2015 Census.
#     * "Total Population": Total Population for US 2015 Census.
#     * "Number of Veterans": Number of Veterans for US 2015 Census.
#     * "Foreign-born": Foreign-born population for US 2015 Census.
#     * "Average Household Size": Average Household Size for US 2015 Census.
#     * "American Indian and Alaska Native": American Indian and Alaska Native population for US 2015 Census.
#     * "Asian": Asian population for US 2015 Census.
#     * "Hispanic or Latino": Hispanic or Latino population for US 2015 Census.
#     * "White": White population for US 2015 Census.

# %%
# %%sql
# SELECT * FROM dim_airports LIMIT 5

# %% [markdown]
# * **dim_airports**:
#     * "region" (PK): Code for states.
#     * "totalAirport": Number of airports in the state (including small, medium, and large airports).

# %%
# %%sql
# SELECT * FROM dim_temperature LIMIT 5

# %% [markdown]
# * **dim_temperature**:
#     * "State Code" (PK): Code for states.
#     * "FallAvgTemp": Average temperature in Fall (Sep, Oct, Nov) from 2003 onwards.
#     * "SummerAvgTemp": Average temperature in Summer (Jun, Jul, Oct) from 2003 onwards.
#     * "	SpringAvgTemp": Average temperature in Spring (Mar, Apr, May) from 2003 onwards.
#     * "WinterAvgTemp": Average temperature in Winter (Dec, Jan, Feb) from 2003 onwards.

# %%
# %%sql
# SELECT * FROM fact_tourists LIMIT 5;

# %% [markdown]
# * **fact_tourists**:
#     * "cicid" (PK): cic id for tourists.
#     * "i94yr": i94 filling year.
#     * "i94mon": i94 filling month.
#     * "i94cit": country codes.
#     * "i94res": country codes.
#     * "i94port": port initials.
#     * "arrdate": Arrival Date in the USA.
#     * "i94mode": 1 = 'Air, '2 = 'Sea', 3 = 'Land', 9 = 'Not reported' ;.
#     * "i94addr" (FK): US state codes.
#     * "depdate": Departure Date from the USA.
#     * "i94bir": Respondant birth year.
#     * "i94visa": visa codes, 1 = Business, 2 = Pleasure, 3 = Student.
#     * "count": Used for summary statistics.
#     * "dtadfile": Date added to I-94 Files.
#     * "visapost":  Department of State where where Visa was issued.
#     * "entdepa": Arrival Flag - admitted or paroled into the U.S..
#     * "entdepd": Departure Flag - Departed, lost I-94 or is deceased.
#     * "matflag": Match flag - Match of arrival and departure records.
#     * "biryear": 4 digit year of birth.
#     * "dtaddto": Date to which admitted to U.S. (allowed to stay until).
#     * "gender": Non-immigrant sex.
#     * "airline": Airline used to arrive in U.S..
#     * "admnum": Admission Number.
#     * "fltno": Flight number of Airline used to arrive in U.S..
#     * "visatype": Class of admission legally admitting the non-immigrant to temporarily stay in U.S..

# %% [markdown]
# #### Step 5: Complete Project Write Up
# * Clearly state the rationale for the choice of tools and technologies for the project.
#     * For this project, we used Python, PySpark, SQL, AWS S3, and AWS Redshift.
#         * Python handles small data well and easily while PySpark deals with big data quite well.
#         * And SQL is a query language which has been used in many DBMSs. And it can also been deployed in Python and PySpark.
#         * We use AWS S3 to keep a copy of all the staging files and copy these staging files directly from S3 to Redshift.
# * Propose how often the data should be updated and why.
#     * The data should be updated monthly since the immigration data is collected monthly while the other data sources are refreshed less frequently.
# * Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#      * Use PySpark to build ETL processes and save all the data as parquet files in S3.
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#      * Use Airflow to schedule the pipelines which connect all the data sources, data warehouse, and the the dashboard.
#  * The database needed to be accessed by 100+ people.
#      * Create IAM User groups for the different users.
